# %% [markdown]
# <a href="https://colab.research.google.com/github/cesar-yoab/Survey-GAINs/blob/main/SurveyGAINs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library import and workspace set-up

# %%
# In case you forgot to import stuff run this cell
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from scipy.special import expit

# %%
use_cuda = torch.cuda.is_available()
device = torch.device('cuda' if use_cuda else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Survey Encoder
# Implementation of survey encoder using variation of  weigh of evidence (WOE) is.
# We define the weight of a category $c$ as:
# \begin{align*}
# W(c) = \log\left(\frac{\text{# of non-}c}{\text{# of }c}\right)
# \end{align*}

# %%
class SurveyEncoder(object):
    def __init__(self, columns='all'):
        self.columns = columns
        self.map = dict()
        self.reverse_map = dict()

    def _fit(self, data):
        raise NotImplementedError
    
    def _transform(self, data):
        """Replace categorical values with the fitted continous values."""
        for col in self.columns:
            data[col] = data[col].replace(self.map[col])

    def fit_transform(self, data):
        """Fit a mapping for the data and return a copy of the 
        data frame but encoded using the fitted mapping."""
        self._fit(data)
        encoded = data.copy()
        self._transform(encoded)
        return encoded

    def decode_imputed(self, imputed):
        """Decodes back to categorical responses."""
        for col in self.columns:
            imputed[col] = imputed[col].replace(self.reverse_map[col])
        
        return imputed

    def smart_decode(self, imputed):
        """Decodes to categorical after passing it through the model."""
        keys = list(self.map.keys())

        for j in range(imputed.shape[1]):
            col_keys = np.array(list(self.reverse_map[keys[j]].keys()))
            imp_col = imputed[:, j]
            for i in range(imputed.shape[0]):
                dist = np.abs(col_keys - imp_col[i])
                imp_col[i] = col_keys[dist.argmin()]

        imputed_df = pd.DataFrame(imputed, columns=self.columns)
        return self.decode_imputed(imputed_df)

# %%
# This what will be ultimately using
class WOEncoder(SurveyEncoder):
    def __init__(self, columns='all'):
        super().__init__(columns)

    def _fit(self, data):
        if self.columns == 'all':
            self.columns = data.columns

        for col in self.columns:
            prop_events = data[col].value_counts(normalize=True)
            prop_nonevents = 1-prop_events

            # convert to dictionary
            prop_events = prop_events.to_dict()
            prop_nonevents = prop_nonevents.to_dict()
            
            col_map = dict()
            col_remap = dict()
            # Calculate WOE
            for k, v in prop_events.items():
                # sigmoid woe
                woe = np.log(prop_nonevents[k]/v)
                col_map[k] = woe
                col_remap[woe] = k
            
            self.map[col] = col_map
            self.reverse_map[col] = col_remap

# %% [markdown]
# # GAIN
# Implementation of our GAIN Networks

# %%
class GAIN(nn.Module):
    def __init__(self, weights):
        super().__init__()
        n_layers = len(weights) - 1

        layers = [nn.Linear(weights[0], weights[1])]
        for i in range(1, n_layers):
            layers.extend([nn.GELU(), nn.Linear(weights[i], weights[i + 1])])

        self.model = nn.Sequential(*layers)

    def forward(self, X, M):
        input = torch.cat(dim=1, tensors=[X, M])
        output = self.model(input)
        return output

# %%
class GAINHyper(object):
    def __init__(self, batch_size=128, lr=1e-4, alpha=1000,
                 epochs=50, p_hint=.9):
        self.batch_size = batch_size
        self.lr = lr
        self.alpha = alpha
        self.epochs = epochs
        self.p_hint = p_hint

# %%
# Helper functions
def mask_data(data, mask, tau=0):
    return mask * data + (1 - mask) * tau

def sample_Z(m, n):
    return np.random.uniform(0., 0.01, size=[m, n])

def sample_M(m, n, p):
    A = np.random.uniform(0., 1., size=[m, n])
    B = A > p
    C = 1. * B

    return C

# Loss functions
def discriminator_loss(M, New_X, H, nets):
    Generator = nets[0]
    Discriminator = nets[1]

    # Generator 
    G_sample = Generator(New_X, M)

    # Combine with original data
    Hat_New_X = New_X * M + G_sample * (1-M)

    # Discriminator
    D_prob = Discriminator(Hat_New_X, H)

    # Loss
    D_loss = -torch.mean(M * torch.log(D_prob + 1e-8) + (1-M) * torch.log(1.-D_prob + 1e-8))
    return D_loss

def generator_loss(X, M, New_X, H, alpha, nets):
    Generator = nets[0]
    Discriminator = nets[1]

    # Generator
    G_sample = Generator(New_X, M)

    # Combine with original data
    Hat_New_X = New_X * M + G_sample * (1-M)

    # Discriminator
    D_prob = Discriminator(Hat_New_X, H)

    # Loss
    G_loss1 = -torch.mean((1-M) * torch.log(D_prob + 1e-8))
    MSE_train_loss = torch.mean((M * New_X - M * G_sample)**2) / torch.mean(M)

    G_loss = G_loss1 + alpha * MSE_train_loss

    return G_loss, MSE_train_loss

# %% [markdown]
# ## Driver code to train the GAIN model

# %%
def train_GAIN(nets, dataloaders, optimizers,
               batch_size=128, alpha=100, 
               p_hint=.9, epochs=50, verbose=True):
    """(Generator, Discriminator), (Data, Mask)"""
    data_loader, mask_loader = dataloaders
    optimizer_G, optimizer_D = optimizers
    # Training the network
    it = 0
    for epoch in range(epochs):
        if verbose:
            print("Epoch: {}".format(epoch))
        # Batch training
        for X_mb, M_mb in zip(data_loader, mask_loader):
            # Must be floats
            X_mb = X_mb
            M_mb = M_mb

            # Noise matrix
            Z_mb = sample_Z(X_mb.shape[0], dims[1])
            Z_mb = torch.tensor(Z_mb, device=device).float()

            # Hint matrix
            H_mb = sample_M(X_mb.shape[0], dims[1], 1-p_hint)
            H_mb = M_mb * torch.tensor(H_mb, device=device).float()

            # Mask data
            X_mask = mask_data(X_mb, M_mb, Z_mb)

            # Discriminator
            optimizer_D.zero_grad()
            D_loss_curr = discriminator_loss(M=M_mb, New_X=X_mask, 
                                             H=H_mb, nets=nets)
            D_loss_curr.backward()
            optimizer_D.step()

            # Generator
            optimizer_G.zero_grad()
            G_loss_curr, MSE_train_loss_curr = generator_loss(X=X_mb, M=M_mb, 
                                                              New_X=X_mask,
                                                              alpha=alpha, 
                                                              H=H_mb, nets=nets)
            G_loss_curr.backward()
            optimizer_G.step()

            if it % 100 == 0 and verbose:
                print("\tIter: {}".format(it))
                print("\tTrain RMSE: {:.4}".format(np.sqrt(MSE_train_loss_curr.item())))
                print()

            it += 1

# %%
def imputator(Generator, X, M, encoder, cuda=False):
    # Convert data set to tensor
    Xtens = torch.tensor(X, device=device).float()
    Mtens = torch.tensor(M, device=device).float()

    imputed_data = Mtens * Xtens + (1-Mtens) * Generator(Xtens, Mtens)
    if cuda:
        imputed_data = imputed_data.cpu().detach().numpy()
    else:
        imputed_data = imputed_data.detach().numpy()

    rmse = np.sqrt(np.mean(X - imputed_data)**2)

    return encoder.smart_decode(imputed_data), rmse

# %%
def imputed_scores(X, imputed):
    score = dict()
    score['RMSE'] = np.sqrt(np.mean(X - imputed)**2)

# %%
def generate_trial_data(X, p_miss=.2, split=.8):
    ### Missing data introduction
    p_miss_vec = p_miss * np.ones((dims[1], 1))
    M = np.zeros(dims)

    for i in range(dims[1]):
        A = np.random.uniform(0., 1., size=[dims[0], ])
        B = A > p_miss_vec[i]
        M[:, i] = 1.*B

    # Train Test division
    idx = np.random.permutation(dims[0])

    Train_no = int(dims[0] * .8)
    Test_no = dims[0] - Train_no

    # Train / Test Features
    trainX = X[idx[:Train_no], :]
    testX = X[idx[Train_no:], :]

    # Train / Test Features
    trainM = M[idx[:Train_no], :]
    testM = M[idx[Train_no:], :]
    return (trainX, testX), (trainM, testM), M

# %% [markdown]
# # Kaggle importation and cleaning

# %%
# Import and load Kaggle survey data
import zipfile

with zipfile.ZipFile('kaggle.zip', 'r') as zipf:
        zipf.extractall('./')    


# Import data and first looks
survey_df = pd.read_csv('kaggle_survey_2020_responses.csv')
# First row contains the question displayed in the survey
#  we create a dict with the column name as key and the question as value
questions = dict(zip(survey_df.columns, survey_df.iloc[0]))

# Then we have to remove the entire first row since it doesn't contain any actual data
survey_df = survey_df.iloc[1::]
survey_df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Time from Start to Finish (seconds)     Q1  ... Q35_B_Part_10 Q35_B_OTHER
# 1                                1838  35-39  ...           NaN         NaN
# 2                              289287  30-34  ...           NaN         NaN
# 3                                 860  35-39  ...          None         NaN
# 4                                 507  30-34  ...           NaN         NaN
# 5                                  78  30-34  ...           NaN         NaN
#
# [5 rows x 355 columns]

# %%
### Preparing data (Selecting columns to use)
test_df = survey_df[['Q1', 'Q2', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q15']]
test_df = test_df.dropna()
subset_df = test_df.copy()
subset_df.head()
# Out:
#       Q1  ...                                    Q15
# 1  35-39  ...                              1-2 years
# 2  30-34  ...                              1-2 years
# 3  35-39  ...  I do not use machine learning methods
# 4  30-34  ...                              3-4 years
# 7  22-24  ...                           Under 1 year
#
# [5 rows x 8 columns]

# %% [markdown]
# # Full Kaggle Data Set Experiment
# In this section we test different architecture and use the best
# performing ones for our longer test with 30 trials and different
# missing values.

# %%
# Encoding data and preparing for training
encoder = WOEncoder()
X_raw = encoder.fit_transform(subset_df)
X = X_raw.values
dims = X.shape

### Missing data introduction
p_miss = .2 # 20% missing data
p_miss_vec = p_miss * np.ones((dims[1], 1))
M = np.zeros(dims)

for i in range(dims[1]):
    A = np.random.uniform(0., 1., size=[dims[0], ])
    B = A > p_miss_vec[i]
    M[:, i] = 1.*B

# Train Test division
idx = np.random.permutation(dims[0])

Train_no = int(dims[0] * .8)
Test_no = dims[0] - Train_no

# Train / Test Features
trainX = X[idx[:Train_no], :]
testX = X[idx[Train_no:], :]

# Train / Test Features
trainM = M[idx[:Train_no], :]
testM = M[idx[Train_no:], :]

# %%
# Hyper params and network architectures
weights = [dims[1]*2, 64, 128, 64, dims[1]]

hyper_params = GAINHyper(batch_size=128, lr=0.001, 
                         alpha=1000, epochs=40, p_hint=.9)

# Data Loaders for training
data_loader = DataLoader(torch.tensor(trainX, device=device).float(), 
                         batch_size=hyper_params.batch_size, 
                         shuffle=False)
mask_loader = DataLoader(torch.tensor(trainM, device=device).float(), 
                         batch_size=hyper_params.batch_size, 
                         shuffle=False)

# Generator and Discriminator
Generator = GAIN(weights=weights).to(device)
Discriminator = GAIN(weights=weights).to(device)

# Optimizers
optimizer_G = optim.Adam(Generator.parameters(), lr=hyper_params.lr)
optimizer_D = optim.Adam(Discriminator.parameters(), lr=hyper_params.lr)

# %%
train_GAIN(nets=(Generator, Discriminator), 
           optimizers=(optimizer_G, optimizer_D),
           dataloaders=(data_loader, mask_loader),
           batch_size=hyper_params.batch_size,
           alpha=hyper_params.alpha,
           p_hint=hyper_params.p_hint,
           epochs=hyper_params.epochs)
# Out:
# Epoch: 0
# 	Iter: 0
# 	Train RMSE: 1.842
#
# 	Iter: 100
# 	Train RMSE: 0.3432
#
# Epoch: 1
# 	Iter: 200
# 	Train RMSE: 0.1237
#
# Epoch: 2
# 	Iter: 300
# 	Train RMSE: 0.08545
#
# Epoch: 3
# 	Iter: 400
# 	Train RMSE: 0.06142
#
# Epoch: 4
# 	Iter: 500
# 	Train RMSE: 0.05136
#
# Epoch: 5
# 	Iter: 600
# 	Train RMSE: 0.04736
#
# Epoch: 6
# 	Iter: 700
# 	Train RMSE: 0.03733
#
# Epoch: 7
# 	Iter: 800
# 	Train RMSE: 0.03746
#
# Epoch: 8
# 	Iter: 900
# 	Train RMSE: 0.03742
#
# Epoch: 9
# 	Iter: 1000
# 	Train RMSE: 0.03548
#
# Epoch: 10
# 	Iter: 1100
# 	Train RMSE: 0.03206
#
# Epoch: 11
# 	Iter: 1200
# 	Train RMSE: 0.02585
#
# Epoch: 12
# 	Iter: 1300
# 	Train RMSE: 0.03202
#
# Epoch: 13
# 	Iter: 1400
# 	Train RMSE: 0.02742
#
# Epoch: 14
# 	Iter: 1500
# 	Train RMSE: 0.03389
#
# Epoch: 15
# 	Iter: 1600
# 	Train RMSE: 0.02969
#
# Epoch: 16
# 	Iter: 1700
# 	Train RMSE: 0.0262
#
# Epoch: 17
# 	Iter: 1800
# 	Train RMSE: 0.02617
#
# Epoch: 18
# 	Iter: 1900
# 	Train RMSE: 0.02489
#
# Epoch: 19
# 	Iter: 2000
# 	Train RMSE: 0.02269
#
# Epoch: 20
# 	Iter: 2100
# 	Train RMSE: 0.02285
#
# Epoch: 21
# 	Iter: 2200
# 	Train RMSE: 0.02055
#
# Epoch: 22
# 	Iter: 2300
# 	Train RMSE: 0.02452
#
# Epoch: 23
# 	Iter: 2400
# 	Train RMSE: 0.01825
#
# Epoch: 24
# 	Iter: 2500
# 	Train RMSE: 0.02079
#
# Epoch: 25
# 	Iter: 2600
# 	Train RMSE: 0.01966
#
# Epoch: 26
# 	Iter: 2700
# 	Train RMSE: 0.01928
#
# Epoch: 27
# 	Iter: 2800
# 	Train RMSE: 0.0185
#
# Epoch: 28
# 	Iter: 2900
# 	Train RMSE: 0.02049
#
# Epoch: 29
# 	Iter: 3000
# 	Train RMSE: 0.02109
#
# Epoch: 30
# 	Iter: 3100
# 	Train RMSE: 0.02383
#
# Epoch: 31
# 	Iter: 3200
# 	Train RMSE: 0.02112
#
# Epoch: 32
# 	Iter: 3300
# 	Train RMSE: 0.02182
#
# Epoch: 33
# 	Iter: 3400
# 	Train RMSE: 0.03029
#
# 	Iter: 3500
# 	Train RMSE: 0.02042
#
# Epoch: 34
# 	Iter: 3600
# 	Train RMSE: 0.01724
#
# Epoch: 35
# 	Iter: 3700
# 	Train RMSE: 0.0205
#
# Epoch: 36
# 	Iter: 3800
# 	Train RMSE: 0.02022
#
# Epoch: 37
# 	Iter: 3900
# 	Train RMSE: 0.02508
#
# Epoch: 38
# 	Iter: 4000
# 	Train RMSE: 0.02039
#
# Epoch: 39
# 	Iter: 4100
# 	Train RMSE: 0.02581

# %% [markdown]
# ### Testing and metrics for single trial
# We notice that its important to split data into a train and test set, this
# should be done to avoid over fitting. When testing on a test set we can see if
# the model generalized by looking at the RMSE, it should be relatively close to
# the train RMSE.

# %%
# Test set
imputed_data, rmse = imputator(Generator, testX, testM, encoder, cuda=True)
testDecoded = encoder.smart_decode(testX)
means = []
for col in imputed_data.columns:
    mean = np.mean(np.where(imputed_data[col].values == testDecoded[col].values, 1, 0))
    means.append(mean)

accuracy = np.mean(np.array(means))
print("RMSE: {}\nAccuracy: {}".format(rmse, accuracy))
# Out:
# RMSE: 0.00819122496624373
# Accuracy: 0.9559923664122139

# %%
# Entire set
imputed_data, rmse = imputator(Generator, X, M, encoder, cuda=True)
means = []
for col in imputed_data.columns:
    mean = np.mean(np.where(imputed_data[col].values == test_df[col].values, 1, 0))
    means.append(mean)

accuracy = np.mean(np.array(means))
print("RMSE: {}\nAccuracy: {}".format(rmse, accuracy))
# Out:
# RMSE: 0.008448171974611719
# Accuracy: 0.9539284841822401

# %% [markdown]
# ## Multiple Trial Training and Testing
# #### Full Kaggle Data Test

# %%
trials = 30
X = X_raw.values
dims = X.shape
pmissing = [.1, .2, .3, .4]
avg_rmses = []
sd_rmses = []
avg_accs = []
sd_accs = []

for p in pmissing:
    print("Test for {}% missing data".format(100*p))
    rmses = []
    accs = []
    for t in range(trials):
        print("Trial {}".format(t))
        #############
        # Preparing #
        #############

        Xt, mt, M = generate_trial_data(X, p_miss=p)
        trainX, testX = Xt
        trainM, testM = mt

        # Hyper params and network architectures
        weights = [dims[1]*2, 64, 128, 64, dims[1]]

        hyper_params = GAINHyper(batch_size=128, lr=0.001, 
                                alpha=1000, epochs=40, p_hint=.9)

        # Data Loaders for training
        data_loader = DataLoader(torch.tensor(trainX, device=device).float(), 
                                batch_size=hyper_params.batch_size, 
                                shuffle=False)
        mask_loader = DataLoader(torch.tensor(trainM, device=device).float(), 
                                batch_size=hyper_params.batch_size, 
                                shuffle=False)

        # Generator and Discriminator
        Generator = GAIN(weights=weights).to(device)
        Discriminator = GAIN(weights=weights).to(device)

        # Optimizers
        optimizer_G = optim.Adam(Generator.parameters(), lr=hyper_params.lr)
        optimizer_D = optim.Adam(Discriminator.parameters(), lr=hyper_params.lr)

        ############
        # Training #
        ############
        train_GAIN(nets=(Generator, Discriminator), 
            optimizers=(optimizer_G, optimizer_D),
            dataloaders=(data_loader, mask_loader),
            batch_size=hyper_params.batch_size,
            alpha=hyper_params.alpha,
            p_hint=hyper_params.p_hint,
            epochs=hyper_params.epochs, verbose=False)
        

        ###########
        # Testing #
        ###########
        # Test set
        imputed_data, rmse = imputator(Generator, testX, testM, encoder, cuda=True)
        testDecoded = encoder.smart_decode(testX)
        means = []
        for col in imputed_data.columns:
            mean = np.mean(np.where(imputed_data[col].values == testDecoded[col].values, 1, 0))
            means.append(mean)

        accuracy = np.mean(np.array(means))
        print("\tTest RMSE: {0:.4f}".format(rmse))
        print("\tTest Accuracy: {0:.4f}".format(accuracy))


        # Entire set
        imputed_data, rmse = imputator(Generator, X, M, encoder, cuda=True)
        testDecoded = encoder.smart_decode(testX)
        means = []
        for col in imputed_data.columns:
            mean = np.mean(np.where(imputed_data[col].values == test_df[col].values, 1, 0))
            means.append(mean)

        accuracy = np.mean(np.array(means))
        print("\tTotal RMSE: {0:.4f}".format(rmse))
        print("\tTotal Accuracy: {0:.4f}".format(accuracy))
        rmses.append(rmse)
        accs.append(accuracy)


    ### Average metrics for experiment

    # RMSE
    mean_rmse = np.mean(np.array(rmses))
    avg_rmses.append(mean_rmse)
    sd_rmses.append(np.std(np.array(rmses)))
    # Accuracy
    mean_acc = np.mean(np.array(accs))
    avg_accs.append(mean_acc)
    sd_accs.append(np.std(np.array(accs)))
    print()
    print('#'*20)
    print("\tMetrics for {}% missing".format(100*p))
    print("\tAvg RMSE: {0:.4f}".format(mean_rmse))
    print("\tAvg Accuracy: {0:.4f}".format(mean_acc))
    print('#'*20)
# Out:
# Test for 10.0% missing data
# Trial 0
# 	Test RMSE: 0.0053
# 	Test Accuracy: 0.9832
# 	Total RMSE: 0.0053
# 	Total Accuracy: 0.9832
# Trial 1
# 	Test RMSE: 0.0047
# 	Test Accuracy: 0.9775
# 	Total RMSE: 0.0046
# 	Total Accuracy: 0.9763
# Trial 2
# 	Test RMSE: 0.0014
# 	Test Accuracy: 0.9787
# 	Total RMSE: 0.0012
# 	Total Accuracy: 0.9778
# Trial 3
# 	Test RMSE: 0.0030
# 	Test Accuracy: 0.9835
# 	Total RMSE: 0.0029
# 	Total Accuracy: 0.9843
# Trial 4
# 	Test RMSE: 0.0035
# 	Test Accuracy: 0.9752
# 	Total RMSE: 0.0036
# 	Total Accuracy: 0.9751
# Trial 5
# 	Test RMSE: 0.0033
# 	Test Accuracy: 0.9726
# 	Total RMSE: 0.0031
# 	Total Accuracy: 0.9733
# Trial 6
# 	Test RMSE: 0.0008
# 	Test Accuracy: 0.9777
# 	Total RMSE: 0.0004
# 	Total Accuracy: 0.9777
# Trial 7
# 	Test RMSE: 0.0069
# 	Test Accuracy: 0.9613
# 	Total RMSE: 0.0069
# 	Total Accuracy: 0.9606
# Trial 8
# 	Test RMSE: 0.0076
# 	Test Accuracy: 0.9769
# 	Total RMSE: 0.0073
# 	Total Accuracy: 0.9776
# Trial 9
# 	Test RMSE: 0.0017
# 	Test Accuracy: 0.9763
# 	Total RMSE: 0.0015
# 	Total Accuracy: 0.9769
# Trial 10
# 	Test RMSE: 0.0007
# 	Test Accuracy: 0.9803
# 	Total RMSE: 0.0013
# 	Total Accuracy: 0.9799
# Trial 11
# 	Test RMSE: 0.0055
# 	Test Accuracy: 0.9727
# 	Total RMSE: 0.0052
# 	Total Accuracy: 0.9736
# Trial 12
# 	Test RMSE: 0.0113
# 	Test Accuracy: 0.9747
# 	Total RMSE: 0.0115
# 	Total Accuracy: 0.9740
# Trial 13
# 	Test RMSE: 0.0012
# 	Test Accuracy: 0.9856
# 	Total RMSE: 0.0014
# 	Total Accuracy: 0.9858
# Trial 14
# 	Test RMSE: 0.0013
# 	Test Accuracy: 0.9895
# 	Total RMSE: 0.0013
# 	Total Accuracy: 0.9901
# Trial 15
# 	Test RMSE: 0.0037
# 	Test Accuracy: 0.9781
# 	Total RMSE: 0.0034
# 	Total Accuracy: 0.9784
# Trial 16
# 	Test RMSE: 0.0001
# 	Test Accuracy: 0.9748
# 	Total RMSE: 0.0000
# 	Total Accuracy: 0.9736
# Trial 17
# 	Test RMSE: 0.0096
# 	Test Accuracy: 0.9783
# 	Total RMSE: 0.0098
# 	Total Accuracy: 0.9796
# Trial 18
# 	Test RMSE: 0.0063
# 	Test Accuracy: 0.9775
# 	Total RMSE: 0.0061
# 	Total Accuracy: 0.9780
# Trial 19
# 	Test RMSE: 0.0010
# 	Test Accuracy: 0.9900
# 	Total RMSE: 0.0010
# 	Total Accuracy: 0.9893
# Trial 20
# 	Test RMSE: 0.0097
# 	Test Accuracy: 0.9735
# 	Total RMSE: 0.0096
# 	Total Accuracy: 0.9728
# Trial 21
# 	Test RMSE: 0.0011
# 	Test Accuracy: 0.9781
# 	Total RMSE: 0.0010
# 	Total Accuracy: 0.9776
# Trial 22
# 	Test RMSE: 0.0000
# 	Test Accuracy: 0.9810
# 	Total RMSE: 0.0003
# 	Total Accuracy: 0.9811
# Trial 23
# 	Test RMSE: 0.0048
# 	Test Accuracy: 0.9730
# 	Total RMSE: 0.0048
# 	Total Accuracy: 0.9738
# Trial 24
# 	Test RMSE: 0.0002
# 	Test Accuracy: 0.9919
# 	Total RMSE: 0.0002
# 	Total Accuracy: 0.9922
# Trial 25
# 	Test RMSE: 0.0019
# 	Test Accuracy: 0.9814
# 	Total RMSE: 0.0020
# 	Total Accuracy: 0.9818
# Trial 26
# 	Test RMSE: 0.0044
# 	Test Accuracy: 0.9901
# 	Total RMSE: 0.0042
# 	Total Accuracy: 0.9896
# Trial 27
# 	Test RMSE: 0.0028
# 	Test Accuracy: 0.9715
# 	Total RMSE: 0.0030
# 	Total Accuracy: 0.9716
# Trial 28
# 	Test RMSE: 0.0028
# 	Test Accuracy: 0.9784
# 	Total RMSE: 0.0030
# 	Total Accuracy: 0.9789
# Trial 29
# 	Test RMSE: 0.0095
# 	Test Accuracy: 0.9724
# 	Total RMSE: 0.0096
# 	Total Accuracy: 0.9723
#
# ####################
# 	Metrics for 10.0% missing
# 	Avg RMSE: 0.0038
# 	Avg Accuracy: 0.9786
# ####################
# Test for 20.0% missing data
# Trial 0
# 	Test RMSE: 0.0004
# 	Test Accuracy: 0.9590
# 	Total RMSE: 0.0000
# 	Total Accuracy: 0.9565
# Trial 1
# 	Test RMSE: 0.0152
# 	Test Accuracy: 0.9445
# 	Total RMSE: 0.0145
# 	Total Accuracy: 0.9469
# Trial 2
# 	Test RMSE: 0.0114
# 	Test Accuracy: 0.9637
# 	Total RMSE: 0.0116
# 	Total Accuracy: 0.9639
# Trial 3
# 	Test RMSE: 0.0051
# 	Test Accuracy: 0.9555
# 	Total RMSE: 0.0052
# 	Total Accuracy: 0.9570
# Trial 4
# 	Test RMSE: 0.0078
# 	Test Accuracy: 0.9777
# 	Total RMSE: 0.0079
# 	Total Accuracy: 0.9781
# Trial 5
# 	Test RMSE: 0.0098
# 	Test Accuracy: 0.9566
# 	Total RMSE: 0.0095
# 	Total Accuracy: 0.9567
# Trial 6
# 	Test RMSE: 0.0165
# 	Test Accuracy: 0.9306
# 	Total RMSE: 0.0165
# 	Total Accuracy: 0.9296
# Trial 7
# 	Test RMSE: 0.0046
# 	Test Accuracy: 0.9734
# 	Total RMSE: 0.0046
# 	Total Accuracy: 0.9733
# Trial 8
# 	Test RMSE: 0.0060
# 	Test Accuracy: 0.9667
# 	Total RMSE: 0.0062
# 	Total Accuracy: 0.9674
# Trial 9
# 	Test RMSE: 0.0003
# 	Test Accuracy: 0.9706
# 	Total RMSE: 0.0002
# 	Total Accuracy: 0.9708
# Trial 10
# 	Test RMSE: 0.0108
# 	Test Accuracy: 0.9366
# 	Total RMSE: 0.0111
# 	Total Accuracy: 0.9355
# Trial 11
# 	Test RMSE: 0.0045
# 	Test Accuracy: 0.9485
# 	Total RMSE: 0.0042
# 	Total Accuracy: 0.9468
# Trial 12
# 	Test RMSE: 0.0110
# 	Test Accuracy: 0.9509
# 	Total RMSE: 0.0107
# 	Total Accuracy: 0.9520
# Trial 13
# 	Test RMSE: 0.0036
# 	Test Accuracy: 0.9690
# 	Total RMSE: 0.0038
# 	Total Accuracy: 0.9678
# Trial 14
# 	Test RMSE: 0.0055
# 	Test Accuracy: 0.9457
# 	Total RMSE: 0.0053
# 	Total Accuracy: 0.9464
# Trial 15
# 	Test RMSE: 0.0151
# 	Test Accuracy: 0.9435
# 	Total RMSE: 0.0146
# 	Total Accuracy: 0.9449
# Trial 16
# 	Test RMSE: 0.0239
# 	Test Accuracy: 0.9304
# 	Total RMSE: 0.0238
# 	Total Accuracy: 0.9308
# Trial 17
# 	Test RMSE: 0.0050
# 	Test Accuracy: 0.9542
# 	Total RMSE: 0.0047
# 	Total Accuracy: 0.9536
# Trial 18
# 	Test RMSE: 0.0128
# 	Test Accuracy: 0.9607
# 	Total RMSE: 0.0128
# 	Total Accuracy: 0.9599
# Trial 19
# 	Test RMSE: 0.0006
# 	Test Accuracy: 0.9559
# 	Total RMSE: 0.0005
# 	Total Accuracy: 0.9554
# Trial 20
# 	Test RMSE: 0.0047
# 	Test Accuracy: 0.9518
# 	Total RMSE: 0.0049
# 	Total Accuracy: 0.9517
# Trial 21
# 	Test RMSE: 0.0001
# 	Test Accuracy: 0.9885
# 	Total RMSE: 0.0001
# 	Total Accuracy: 0.9884
# Trial 22
# 	Test RMSE: 0.0019
# 	Test Accuracy: 0.9673
# 	Total RMSE: 0.0024
# 	Total Accuracy: 0.9668
# Trial 23
# 	Test RMSE: 0.0063
# 	Test Accuracy: 0.9354
# 	Total RMSE: 0.0063
# 	Total Accuracy: 0.9352
# Trial 24
# 	Test RMSE: 0.0107
# 	Test Accuracy: 0.9802
# 	Total RMSE: 0.0108
# 	Total Accuracy: 0.9800
# Trial 25
# 	Test RMSE: 0.0144
# 	Test Accuracy: 0.9547
# 	Total RMSE: 0.0137
# 	Total Accuracy: 0.9573
# Trial 26
# 	Test RMSE: 0.0256
# 	Test Accuracy: 0.9716
# 	Total RMSE: 0.0258
# 	Total Accuracy: 0.9735
# Trial 27
# 	Test RMSE: 0.0105
# 	Test Accuracy: 0.9527
# 	Total RMSE: 0.0104
# 	Total Accuracy: 0.9538
# Trial 28
# 	Test RMSE: 0.0026
# 	Test Accuracy: 0.9856
# 	Total RMSE: 0.0024
# 	Total Accuracy: 0.9853
# Trial 29
# 	Test RMSE: 0.0136
# 	Test Accuracy: 0.9660
# 	Total RMSE: 0.0139
# 	Total Accuracy: 0.9657
#
# ####################
# 	Metrics for 20.0% missing
# 	Avg RMSE: 0.0086
# 	Avg Accuracy: 0.9584
# ####################
# Test for 30.0% missing data
# Trial 0
# 	Test RMSE: 0.0042
# 	Test Accuracy: 0.9544
# 	Total RMSE: 0.0037
# 	Total Accuracy: 0.9531
# Trial 1
# 	Test RMSE: 0.0092
# 	Test Accuracy: 0.9502
# 	Total RMSE: 0.0092
# 	Total Accuracy: 0.9507
# Trial 2
# 	Test RMSE: 0.0272
# 	Test Accuracy: 0.9236
# 	Total RMSE: 0.0279
# 	Total Accuracy: 0.9228
# Trial 3
# 	Test RMSE: 0.0196
# 	Test Accuracy: 0.9733
# 	Total RMSE: 0.0200
# 	Total Accuracy: 0.9750
# Trial 4
# 	Test RMSE: 0.0045
# 	Test Accuracy: 0.9645
# 	Total RMSE: 0.0044
# 	Total Accuracy: 0.9639
# Trial 5
# 	Test RMSE: 0.0012
# 	Test Accuracy: 0.9233
# 	Total RMSE: 0.0004
# 	Total Accuracy: 0.9230
# Trial 6
# 	Test RMSE: 0.0042
# 	Test Accuracy: 0.9311
# 	Total RMSE: 0.0046
# 	Total Accuracy: 0.9300
# Trial 7
# 	Test RMSE: 0.0341
# 	Test Accuracy: 0.8771
# 	Total RMSE: 0.0327
# 	Total Accuracy: 0.8801
# Trial 8
# 	Test RMSE: 0.0037
# 	Test Accuracy: 0.9483
# 	Total RMSE: 0.0038
# 	Total Accuracy: 0.9475
# Trial 9
# 	Test RMSE: 0.0020
# 	Test Accuracy: 0.9287
# 	Total RMSE: 0.0022
# 	Total Accuracy: 0.9263
# Trial 10
# 	Test RMSE: 0.0068
# 	Test Accuracy: 0.9581
# 	Total RMSE: 0.0060
# 	Total Accuracy: 0.9571
# Trial 11
# 	Test RMSE: 0.0112
# 	Test Accuracy: 0.9548
# 	Total RMSE: 0.0111
# 	Total Accuracy: 0.9550
# Trial 12
# 	Test RMSE: 0.0101
# 	Test Accuracy: 0.9571
# 	Total RMSE: 0.0100
# 	Total Accuracy: 0.9577
# Trial 13
# 	Test RMSE: 0.0075
# 	Test Accuracy: 0.9349
# 	Total RMSE: 0.0081
# 	Total Accuracy: 0.9331
# Trial 14
# 	Test RMSE: 0.0222
# 	Test Accuracy: 0.9485
# 	Total RMSE: 0.0223
# 	Total Accuracy: 0.9463
# Trial 15
# 	Test RMSE: 0.0077
# 	Test Accuracy: 0.9170
# 	Total RMSE: 0.0075
# 	Total Accuracy: 0.9176
# Trial 16
# 	Test RMSE: 0.0014
# 	Test Accuracy: 0.9344
# 	Total RMSE: 0.0015
# 	Total Accuracy: 0.9342
# Trial 17
# 	Test RMSE: 0.0014
# 	Test Accuracy: 0.9650
# 	Total RMSE: 0.0020
# 	Total Accuracy: 0.9642
# Trial 18
# 	Test RMSE: 0.0196
# 	Test Accuracy: 0.9523
# 	Total RMSE: 0.0199
# 	Total Accuracy: 0.9529
# Trial 19
# 	Test RMSE: 0.0070
# 	Test Accuracy: 0.9422
# 	Total RMSE: 0.0070
# 	Total Accuracy: 0.9411
# Trial 20
# 	Test RMSE: 0.0031
# 	Test Accuracy: 0.9648
# 	Total RMSE: 0.0036
# 	Total Accuracy: 0.9624
# Trial 21
# 	Test RMSE: 0.0030
# 	Test Accuracy: 0.9577
# 	Total RMSE: 0.0027
# 	Total Accuracy: 0.9570
# Trial 22
# 	Test RMSE: 0.0229
# 	Test Accuracy: 0.9426
# 	Total RMSE: 0.0227
# 	Total Accuracy: 0.9434
# Trial 23
# 	Test RMSE: 0.0082
# 	Test Accuracy: 0.9490
# 	Total RMSE: 0.0083
# 	Total Accuracy: 0.9477
# Trial 24
# 	Test RMSE: 0.0071
# 	Test Accuracy: 0.9273
# 	Total RMSE: 0.0067
# 	Total Accuracy: 0.9256
# Trial 25
# 	Test RMSE: 0.0050
# 	Test Accuracy: 0.9345
# 	Total RMSE: 0.0047
# 	Total Accuracy: 0.9345
# Trial 26
# 	Test RMSE: 0.0237
# 	Test Accuracy: 0.9217
# 	Total RMSE: 0.0237
# 	Total Accuracy: 0.9224
# Trial 27
# 	Test RMSE: 0.0157
# 	Test Accuracy: 0.9155
# 	Total RMSE: 0.0156
# 	Total Accuracy: 0.9156
# Trial 28
# 	Test RMSE: 0.0003
# 	Test Accuracy: 0.9642
# 	Total RMSE: 0.0004
# 	Total Accuracy: 0.9633
# Trial 29
# 	Test RMSE: 0.0134
# 	Test Accuracy: 0.9427
# 	Total RMSE: 0.0132
# 	Total Accuracy: 0.9437
#
# ####################
# 	Metrics for 30.0% missing
# 	Avg RMSE: 0.0102
# 	Avg Accuracy: 0.9416
# ####################
# Test for 40.0% missing data
# Trial 0
# 	Test RMSE: 0.0110
# 	Test Accuracy: 0.9124
# 	Total RMSE: 0.0092
# 	Total Accuracy: 0.9139
# Trial 1
# 	Test RMSE: 0.0165
# 	Test Accuracy: 0.9528
# 	Total RMSE: 0.0160
# 	Total Accuracy: 0.9535
# Trial 2
# 	Test RMSE: 0.0187
# 	Test Accuracy: 0.9541
# 	Total RMSE: 0.0189
# 	Total Accuracy: 0.9521
# Trial 3
# 	Test RMSE: 0.0106
# 	Test Accuracy: 0.8739
# 	Total RMSE: 0.0100
# 	Total Accuracy: 0.8755
# Trial 4
# 	Test RMSE: 0.0011
# 	Test Accuracy: 0.9285
# 	Total RMSE: 0.0014
# 	Total Accuracy: 0.9300
# Trial 5
# 	Test RMSE: 0.0518
# 	Test Accuracy: 0.8995
# 	Total RMSE: 0.0513
# 	Total Accuracy: 0.9010
# Trial 6
# 	Test RMSE: 0.0044
# 	Test Accuracy: 0.9162
# 	Total RMSE: 0.0037
# 	Total Accuracy: 0.9125
# Trial 7
# 	Test RMSE: 0.0031
# 	Test Accuracy: 0.9129
# 	Total RMSE: 0.0028
# 	Total Accuracy: 0.9150
# Trial 8
# 	Test RMSE: 0.0121
# 	Test Accuracy: 0.9241
# 	Total RMSE: 0.0118
# 	Total Accuracy: 0.9253
# Trial 9
# 	Test RMSE: 0.0227
# 	Test Accuracy: 0.9300
# 	Total RMSE: 0.0224
# 	Total Accuracy: 0.9282
# Trial 10
# 	Test RMSE: 0.0068
# 	Test Accuracy: 0.9347
# 	Total RMSE: 0.0066
# 	Total Accuracy: 0.9321
# Trial 11
# 	Test RMSE: 0.0031
# 	Test Accuracy: 0.9265
# 	Total RMSE: 0.0036
# 	Total Accuracy: 0.9294
# Trial 12
# 	Test RMSE: 0.0343
# 	Test Accuracy: 0.8844
# 	Total RMSE: 0.0335
# 	Total Accuracy: 0.8882
# Trial 13
# 	Test RMSE: 0.0012
# 	Test Accuracy: 0.9251
# 	Total RMSE: 0.0011
# 	Total Accuracy: 0.9261
# Trial 14
# 	Test RMSE: 0.0452
# 	Test Accuracy: 0.8766
# 	Total RMSE: 0.0455
# 	Total Accuracy: 0.8768
# Trial 15
# 	Test RMSE: 0.0084
# 	Test Accuracy: 0.9082
# 	Total RMSE: 0.0080
# 	Total Accuracy: 0.9096
# Trial 16
# 	Test RMSE: 0.0051
# 	Test Accuracy: 0.8915
# 	Total RMSE: 0.0043
# 	Total Accuracy: 0.8983
# Trial 17
# 	Test RMSE: 0.0067
# 	Test Accuracy: 0.8947
# 	Total RMSE: 0.0073
# 	Total Accuracy: 0.8944
# Trial 18
# 	Test RMSE: 0.0209
# 	Test Accuracy: 0.8765
# 	Total RMSE: 0.0209
# 	Total Accuracy: 0.8788
# Trial 19
# 	Test RMSE: 0.0044
# 	Test Accuracy: 0.8915
# 	Total RMSE: 0.0044
# 	Total Accuracy: 0.8916
# Trial 20
# 	Test RMSE: 0.0136
# 	Test Accuracy: 0.9146
# 	Total RMSE: 0.0132
# 	Total Accuracy: 0.9126
# Trial 21
# 	Test RMSE: 0.0028
# 	Test Accuracy: 0.9270
# 	Total RMSE: 0.0035
# 	Total Accuracy: 0.9241
# Trial 22
# 	Test RMSE: 0.0164
# 	Test Accuracy: 0.9411
# 	Total RMSE: 0.0156
# 	Total Accuracy: 0.9396
# Trial 23
# 	Test RMSE: 0.0043
# 	Test Accuracy: 0.9436
# 	Total RMSE: 0.0042
# 	Total Accuracy: 0.9455
# Trial 24
# 	Test RMSE: 0.0198
# 	Test Accuracy: 0.9119
# 	Total RMSE: 0.0197
# 	Total Accuracy: 0.9119
# Trial 25
# 	Test RMSE: 0.0070
# 	Test Accuracy: 0.9106
# 	Total RMSE: 0.0066
# 	Total Accuracy: 0.9119
# Trial 26
# 	Test RMSE: 0.0046
# 	Test Accuracy: 0.9272
# 	Total RMSE: 0.0042
# 	Total Accuracy: 0.9268
# Trial 27
# 	Test RMSE: 0.0158
# 	Test Accuracy: 0.9077
# 	Total RMSE: 0.0153
# 	Total Accuracy: 0.9073
# Trial 28
# 	Test RMSE: 0.0111
# 	Test Accuracy: 0.9112
# 	Total RMSE: 0.0112
# 	Total Accuracy: 0.9116
# Trial 29
# 	Test RMSE: 0.0011
# 	Test Accuracy: 0.9438
# 	Total RMSE: 0.0014
# 	Total Accuracy: 0.9453
#
# ####################
# 	Metrics for 40.0% missing
# 	Avg RMSE: 0.0126
# 	Avg Accuracy: 0.9156
# ####################

# %% [markdown]
# ### Notes on first test
# The network performs better when there is more missing data,
# however this may vary depending on the dataset and its dimensions

# %%
results = pd.DataFrame({'PMissing': pmissing, 
                        'FullKaggleRMSE': avg_rmses, 
                        'FullKaggleAcc': avg_accs, 
                        'FullKaggleSdRMSE': sd_rmses,
                        'FullKaggleSdAcc': sd_accs})
#results.to_csv("gain_results.csv")
#
results.head()
# Out:
#    PMissing  FullKaggleRMSE  FullKaggleAcc  FullKaggleSdRMSE  FullKaggleSdAcc
# 0       0.1        0.003842       0.978563          0.003149         0.006506
# 1       0.2        0.008603       0.958363          0.006427         0.015054
# 2       0.3        0.010202       0.941573          0.008683         0.019399
# 3       0.4        0.012585       0.915620          0.012169         0.021049

# %%
results.to_csv("gain_results2_06-12-2020.csv")

# %% [markdown]
# # 1000 Samples Kaggle Data Experiment

# %%
# Encoding data and preparing for training
encoder = WOEncoder()
X_raw = encoder.fit_transform(subset_df)
X = X_raw.values

# select only 1000 samples
sampler = np.random.permutation(X.shape[0])
X = X[sampler[:1000], :]
dims = X.shape

test_df = pd.DataFrame(test_df.values[sampler[:1000], :], columns=test_df.columns)

### Missing data introduction
p_miss = .2 # 20% missing data
p_miss_vec = p_miss * np.ones((dims[1], 1))
M = np.zeros(dims)

for i in range(dims[1]):
    A = np.random.uniform(0., 1., size=[dims[0], ])
    B = A > p_miss_vec[i]
    M[:, i] = 1.*B

# Train Test division
idx = np.random.permutation(dims[0])

Train_no = int(dims[0] * .8)
Test_no = dims[0] - Train_no

# Train / Test Features
trainX = X[idx[:Train_no], :]
testX = X[idx[Train_no:], :]

# Train / Test Features
trainM = M[idx[:Train_no], :]
testM = M[idx[Train_no:], :]

# %%
# Hyper params and network architectures
weights = [dims[1]*2, 64, 128, 64, dims[1]]

hyper_params = GAINHyper(batch_size=32, lr=0.001, 
                         alpha=100, epochs=30, p_hint=.9)

# Data Loaders for training
data_loader = DataLoader(torch.tensor(trainX, device=device).float(), 
                         batch_size=hyper_params.batch_size, 
                         shuffle=False)
mask_loader = DataLoader(torch.tensor(trainM, device=device).float(), 
                         batch_size=hyper_params.batch_size, 
                         shuffle=False)

# Generator and Discriminator
Generator = GAIN(weights=weights).to(device)
Discriminator = GAIN(weights=weights).to(device)

# Optimizers
optimizer_G = optim.Adam(Generator.parameters(), lr=hyper_params.lr)
optimizer_D = optim.Adam(Discriminator.parameters(), lr=hyper_params.lr)

# %%
train_GAIN(nets=(Generator, Discriminator), 
           optimizers=(optimizer_G, optimizer_D),
           dataloaders=(data_loader, mask_loader),
           batch_size=hyper_params.batch_size,
           alpha=hyper_params.alpha,
           p_hint=hyper_params.p_hint,
           epochs=hyper_params.epochs, verbose=False)

# %% [markdown]
# ### Testing and metrics for single experiment

# %%
# Test set
imputed_data, rmse = imputator(Generator, testX, testM, encoder, cuda=True)
testDecoded = encoder.smart_decode(testX)
means = []
for col in imputed_data.columns:
    mean = np.mean(np.where(imputed_data[col].values == testDecoded[col].values, 1, 0))
    means.append(mean)

accuracy = np.mean(np.array(means))
print("RMSE: {}\nAccuracy: {}".format(rmse, accuracy))
# Out:
# RMSE: 0.0044505285752466225
# Accuracy: 0.975625

# %%
# Entire set
imputed_data, rmse = imputator(Generator, X, M, encoder, cuda=True)

means = []
for col in imputed_data.columns:
    mean = np.mean(np.where(imputed_data[col].values == test_df[col].values, 1, 0))
    means.append(mean)

accuracy = np.mean(np.array(means))
print("RMSE: {}\nAccuracy: {}".format(rmse, accuracy))
# Out:
# RMSE: 0.0045422498766494995
# Accuracy: 0.974

# %% [markdown]
# ## Multiple Trial Training and Testing

# %%
# Encoding data and preparing for training
encoder = WOEncoder()
X_raw = encoder.fit_transform(subset_df)
X = X_raw.values

# select only 1000 samples
sampler = np.random.permutation(X.shape[0])
X = X[sampler[:1000], :]
dims = X.shape

test_df = pd.DataFrame(test_df.values[sampler[:1000], :], columns=test_df.columns)

# %%
trials = 30
pmissing = [.1, .2, .3, .4]
avg_rmses = []
sd_rmses = []
avg_accs = []
sd_accs = []

print("SurvGAIN test on Kaggle {} samples".format(dims[0]))

for p in pmissing:
    print("Test for {}% missing data".format(100*p))
    rmses = []
    accs = []
    for t in range(trials):
        print("Trial {}".format(t))
        #############
        # Preparing #
        #############

        Xt, mt, M = generate_trial_data(X, p_miss=p)
        trainX, testX = Xt
        trainM, testM = mt

        # Hyper params and network architectures
        weights = [dims[1]*2, 64, 128, 64, dims[1]]

        hyper_params = GAINHyper(batch_size=32, lr=0.001, 
                                alpha=100, epochs=30, p_hint=.9)

        # Data Loaders for training
        data_loader = DataLoader(torch.tensor(trainX, device=device).float(), 
                                batch_size=hyper_params.batch_size, 
                                shuffle=False)
        mask_loader = DataLoader(torch.tensor(trainM, device=device).float(), 
                                batch_size=hyper_params.batch_size, 
                                shuffle=False)

        # Generator and Discriminator
        Generator = GAIN(weights=weights).to(device)
        Discriminator = GAIN(weights=weights).to(device)

        # Optimizers
        optimizer_G = optim.Adam(Generator.parameters(), lr=hyper_params.lr)
        optimizer_D = optim.Adam(Discriminator.parameters(), lr=hyper_params.lr)

        ############
        # Training #
        ############
        train_GAIN(nets=(Generator, Discriminator), 
            optimizers=(optimizer_G, optimizer_D),
            dataloaders=(data_loader, mask_loader),
            batch_size=hyper_params.batch_size,
            alpha=hyper_params.alpha,
            p_hint=hyper_params.p_hint,
            epochs=hyper_params.epochs, verbose=False)
        

        ###########
        # Testing #
        ###########
        # Test set
        imputed_data, rmse = imputator(Generator, testX, testM, encoder, cuda=True)
        testDecoded = encoder.smart_decode(testX)
        means = []
        for col in imputed_data.columns:
            mean = np.mean(np.where(imputed_data[col].values == testDecoded[col].values, 1, 0))
            means.append(mean)

        accuracy = np.mean(np.array(means))
        print("\tTest RMSE: {0:.4f}".format(rmse))
        print("\tTest Accuracy: {0:.4f}".format(accuracy))


        # Entire set
        imputed_data, rmse = imputator(Generator, X, M, encoder, cuda=True)
        testDecoded = encoder.smart_decode(testX)
        means = []
        for col in imputed_data.columns:
            mean = np.mean(np.where(imputed_data[col].values == test_df[col].values, 1, 0))
            means.append(mean)

        accuracy = np.mean(np.array(means))
        print("\tTotal RMSE: {0:.4f}".format(rmse))
        print("\tTotal Accuracy: {0:.4f}".format(accuracy))
        rmses.append(rmse)
        accs.append(accuracy)


    ### Average metrics for experiment

    # RMSE
    mean_rmse = np.mean(np.array(rmses))
    avg_rmses.append(mean_rmse)
    sd_rmses.append(np.std(np.array(rmses)))
    # Accuracy
    mean_acc = np.mean(np.array(accs))
    avg_accs.append(mean_acc)
    sd_accs.append(np.std(np.array(accs)))
    print()
    print('#'*20)
    print("\tMetrics for {}% missing".format(100*p))
    print("\tAvg RMSE: {0:.4f}".format(mean_rmse))
    print("\tAvg Accuracy: {0:.4f}".format(mean_acc))
    print('#'*20)
# Out:
# SurvGAIN test on Kaggle 1000 samples
# Test for 10.0% missing data
# Trial 0
# 	Test RMSE: 0.0064
# 	Test Accuracy: 0.9888
# 	Total RMSE: 0.0068
# 	Total Accuracy: 0.9855
# Trial 1
# 	Test RMSE: 0.0013
# 	Test Accuracy: 0.9888
# 	Total RMSE: 0.0018
# 	Total Accuracy: 0.9881
# Trial 2
# 	Test RMSE: 0.0025
# 	Test Accuracy: 0.9756
# 	Total RMSE: 0.0038
# 	Total Accuracy: 0.9751
# Trial 3
# 	Test RMSE: 0.0064
# 	Test Accuracy: 0.9675
# 	Total RMSE: 0.0081
# 	Total Accuracy: 0.9689
# Trial 4
# 	Test RMSE: 0.0055
# 	Test Accuracy: 0.9862
# 	Total RMSE: 0.0058
# 	Total Accuracy: 0.9831
# Trial 5
# 	Test RMSE: 0.0031
# 	Test Accuracy: 0.9856
# 	Total RMSE: 0.0027
# 	Total Accuracy: 0.9799
# Trial 6
# 	Test RMSE: 0.0012
# 	Test Accuracy: 0.9900
# 	Total RMSE: 0.0022
# 	Total Accuracy: 0.9873
# Trial 7
# 	Test RMSE: 0.0032
# 	Test Accuracy: 0.9888
# 	Total RMSE: 0.0034
# 	Total Accuracy: 0.9879
# Trial 8
# 	Test RMSE: 0.0003
# 	Test Accuracy: 0.9744
# 	Total RMSE: 0.0002
# 	Total Accuracy: 0.9748
# Trial 9
# 	Test RMSE: 0.0020
# 	Test Accuracy: 0.9719
# 	Total RMSE: 0.0034
# 	Total Accuracy: 0.9721
# Trial 10
# 	Test RMSE: 0.0065
# 	Test Accuracy: 0.9838
# 	Total RMSE: 0.0071
# 	Total Accuracy: 0.9790
# Trial 11
# 	Test RMSE: 0.0023
# 	Test Accuracy: 0.9925
# 	Total RMSE: 0.0020
# 	Total Accuracy: 0.9915
# Trial 12
# 	Test RMSE: 0.0060
# 	Test Accuracy: 0.9900
# 	Total RMSE: 0.0061
# 	Total Accuracy: 0.9859
# Trial 13
# 	Test RMSE: 0.0045
# 	Test Accuracy: 0.9769
# 	Total RMSE: 0.0031
# 	Total Accuracy: 0.9816
# Trial 14
# 	Test RMSE: 0.0048
# 	Test Accuracy: 0.9794
# 	Total RMSE: 0.0039
# 	Total Accuracy: 0.9755
# Trial 15
# 	Test RMSE: 0.0035
# 	Test Accuracy: 0.9788
# 	Total RMSE: 0.0029
# 	Total Accuracy: 0.9778
# Trial 16
# 	Test RMSE: 0.0013
# 	Test Accuracy: 0.9819
# 	Total RMSE: 0.0017
# 	Total Accuracy: 0.9766
# Trial 17
# 	Test RMSE: 0.0146
# 	Test Accuracy: 0.9763
# 	Total RMSE: 0.0142
# 	Total Accuracy: 0.9741
# Trial 18
# 	Test RMSE: 0.0063
# 	Test Accuracy: 0.9850
# 	Total RMSE: 0.0056
# 	Total Accuracy: 0.9865
# Trial 19
# 	Test RMSE: 0.0016
# 	Test Accuracy: 0.9900
# 	Total RMSE: 0.0006
# 	Total Accuracy: 0.9919
# Trial 20
# 	Test RMSE: 0.0010
# 	Test Accuracy: 0.9863
# 	Total RMSE: 0.0017
# 	Total Accuracy: 0.9847
# Trial 21
# 	Test RMSE: 0.0045
# 	Test Accuracy: 0.9844
# 	Total RMSE: 0.0033
# 	Total Accuracy: 0.9830
# Trial 22
# 	Test RMSE: 0.0008
# 	Test Accuracy: 0.9850
# 	Total RMSE: 0.0015
# 	Total Accuracy: 0.9855
# Trial 23
# 	Test RMSE: 0.0009
# 	Test Accuracy: 0.9956
# 	Total RMSE: 0.0012
# 	Total Accuracy: 0.9909
# Trial 24
# 	Test RMSE: 0.0041
# 	Test Accuracy: 0.9856
# 	Total RMSE: 0.0036
# 	Total Accuracy: 0.9864
# Trial 25
# 	Test RMSE: 0.0015
# 	Test Accuracy: 0.9831
# 	Total RMSE: 0.0028
# 	Total Accuracy: 0.9829
# Trial 26
# 	Test RMSE: 0.0044
# 	Test Accuracy: 0.9894
# 	Total RMSE: 0.0057
# 	Total Accuracy: 0.9872
# Trial 27
# 	Test RMSE: 0.0048
# 	Test Accuracy: 0.9838
# 	Total RMSE: 0.0043
# 	Total Accuracy: 0.9799
# Trial 28
# 	Test RMSE: 0.0026
# 	Test Accuracy: 0.9919
# 	Total RMSE: 0.0026
# 	Total Accuracy: 0.9908
# Trial 29
# 	Test RMSE: 0.0075
# 	Test Accuracy: 0.9812
# 	Total RMSE: 0.0082
# 	Total Accuracy: 0.9804
#
# ####################
# 	Metrics for 10.0% missing
# 	Avg RMSE: 0.0040
# 	Avg Accuracy: 0.9825
# ####################
# Test for 20.0% missing data
# Trial 0
# 	Test RMSE: 0.0110
# 	Test Accuracy: 0.9662
# 	Total RMSE: 0.0106
# 	Total Accuracy: 0.9649
# Trial 1
# 	Test RMSE: 0.0133
# 	Test Accuracy: 0.9650
# 	Total RMSE: 0.0137
# 	Total Accuracy: 0.9674
# Trial 2
# 	Test RMSE: 0.0156
# 	Test Accuracy: 0.9506
# 	Total RMSE: 0.0123
# 	Total Accuracy: 0.9561
# Trial 3
# 	Test RMSE: 0.0004
# 	Test Accuracy: 0.9594
# 	Total RMSE: 0.0004
# 	Total Accuracy: 0.9601
# Trial 4
# 	Test RMSE: 0.0009
# 	Test Accuracy: 0.9637
# 	Total RMSE: 0.0002
# 	Total Accuracy: 0.9601
# Trial 5
# 	Test RMSE: 0.0010
# 	Test Accuracy: 0.9575
# 	Total RMSE: 0.0028
# 	Total Accuracy: 0.9629
# Trial 6
# 	Test RMSE: 0.0133
# 	Test Accuracy: 0.9712
# 	Total RMSE: 0.0112
# 	Total Accuracy: 0.9714
# Trial 7
# 	Test RMSE: 0.0059
# 	Test Accuracy: 0.9581
# 	Total RMSE: 0.0056
# 	Total Accuracy: 0.9560
# Trial 8
# 	Test RMSE: 0.0080
# 	Test Accuracy: 0.9413
# 	Total RMSE: 0.0072
# 	Total Accuracy: 0.9487
# Trial 9
# 	Test RMSE: 0.0002
# 	Test Accuracy: 0.9600
# 	Total RMSE: 0.0006
# 	Total Accuracy: 0.9635
# Trial 10
# 	Test RMSE: 0.0063
# 	Test Accuracy: 0.9481
# 	Total RMSE: 0.0063
# 	Total Accuracy: 0.9416
# Trial 11
# 	Test RMSE: 0.0044
# 	Test Accuracy: 0.9756
# 	Total RMSE: 0.0051
# 	Total Accuracy: 0.9700
# Trial 12
# 	Test RMSE: 0.0092
# 	Test Accuracy: 0.9563
# 	Total RMSE: 0.0080
# 	Total Accuracy: 0.9557
# Trial 13
# 	Test RMSE: 0.0114
# 	Test Accuracy: 0.9475
# 	Total RMSE: 0.0095
# 	Total Accuracy: 0.9489
# Trial 14
# 	Test RMSE: 0.0047
# 	Test Accuracy: 0.9662
# 	Total RMSE: 0.0030
# 	Total Accuracy: 0.9729
# Trial 15
# 	Test RMSE: 0.0051
# 	Test Accuracy: 0.9712
# 	Total RMSE: 0.0048
# 	Total Accuracy: 0.9724
# Trial 16
# 	Test RMSE: 0.0080
# 	Test Accuracy: 0.9500
# 	Total RMSE: 0.0087
# 	Total Accuracy: 0.9534
# Trial 17
# 	Test RMSE: 0.0031
# 	Test Accuracy: 0.9619
# 	Total RMSE: 0.0007
# 	Total Accuracy: 0.9569
# Trial 18
# 	Test RMSE: 0.0024
# 	Test Accuracy: 0.9675
# 	Total RMSE: 0.0049
# 	Total Accuracy: 0.9710
# Trial 19
# 	Test RMSE: 0.0078
# 	Test Accuracy: 0.9469
# 	Total RMSE: 0.0069
# 	Total Accuracy: 0.9463
# Trial 20
# 	Test RMSE: 0.0103
# 	Test Accuracy: 0.9531
# 	Total RMSE: 0.0096
# 	Total Accuracy: 0.9526
# Trial 21
# 	Test RMSE: 0.0022
# 	Test Accuracy: 0.9525
# 	Total RMSE: 0.0033
# 	Total Accuracy: 0.9506
# Trial 22
# 	Test RMSE: 0.0026
# 	Test Accuracy: 0.9531
# 	Total RMSE: 0.0016
# 	Total Accuracy: 0.9489
# Trial 23
# 	Test RMSE: 0.0071
# 	Test Accuracy: 0.9738
# 	Total RMSE: 0.0043
# 	Total Accuracy: 0.9730
# Trial 24
# 	Test RMSE: 0.0187
# 	Test Accuracy: 0.9706
# 	Total RMSE: 0.0182
# 	Total Accuracy: 0.9696
# Trial 25
# 	Test RMSE: 0.0097
# 	Test Accuracy: 0.9419
# 	Total RMSE: 0.0130
# 	Total Accuracy: 0.9330
# Trial 26
# 	Test RMSE: 0.0055
# 	Test Accuracy: 0.9663
# 	Total RMSE: 0.0051
# 	Total Accuracy: 0.9660
# Trial 27
# 	Test RMSE: 0.0058
# 	Test Accuracy: 0.9775
# 	Total RMSE: 0.0067
# 	Total Accuracy: 0.9776
# Trial 28
# 	Test RMSE: 0.0110
# 	Test Accuracy: 0.9525
# 	Total RMSE: 0.0104
# 	Total Accuracy: 0.9623
# Trial 29
# 	Test RMSE: 0.0054
# 	Test Accuracy: 0.9537
# 	Total RMSE: 0.0030
# 	Total Accuracy: 0.9479
#
# ####################
# 	Metrics for 20.0% missing
# 	Avg RMSE: 0.0066
# 	Avg Accuracy: 0.9594
# ####################
# Test for 30.0% missing data
# Trial 0
# 	Test RMSE: 0.0133
# 	Test Accuracy: 0.9413
# 	Total RMSE: 0.0118
# 	Total Accuracy: 0.9426
# Trial 1
# 	Test RMSE: 0.0001
# 	Test Accuracy: 0.9494
# 	Total RMSE: 0.0007
# 	Total Accuracy: 0.9476
# Trial 2
# 	Test RMSE: 0.0022
# 	Test Accuracy: 0.9412
# 	Total RMSE: 0.0018
# 	Total Accuracy: 0.9435
# Trial 3
# 	Test RMSE: 0.0210
# 	Test Accuracy: 0.9656
# 	Total RMSE: 0.0205
# 	Total Accuracy: 0.9681
# Trial 4
# 	Test RMSE: 0.0210
# 	Test Accuracy: 0.9412
# 	Total RMSE: 0.0214
# 	Total Accuracy: 0.9454
# Trial 5
# 	Test RMSE: 0.0022
# 	Test Accuracy: 0.9500
# 	Total RMSE: 0.0024
# 	Total Accuracy: 0.9553
# Trial 6
# 	Test RMSE: 0.0168
# 	Test Accuracy: 0.9394
# 	Total RMSE: 0.0165
# 	Total Accuracy: 0.9420
# Trial 7
# 	Test RMSE: 0.0038
# 	Test Accuracy: 0.9381
# 	Total RMSE: 0.0066
# 	Total Accuracy: 0.9340
# Trial 8
# 	Test RMSE: 0.0111
# 	Test Accuracy: 0.9506
# 	Total RMSE: 0.0097
# 	Total Accuracy: 0.9603
# Trial 9
# 	Test RMSE: 0.0284
# 	Test Accuracy: 0.9444
# 	Total RMSE: 0.0284
# 	Total Accuracy: 0.9346
# Trial 10
# 	Test RMSE: 0.0361
# 	Test Accuracy: 0.9287
# 	Total RMSE: 0.0372
# 	Total Accuracy: 0.9311
# Trial 11
# 	Test RMSE: 0.0296
# 	Test Accuracy: 0.9200
# 	Total RMSE: 0.0298
# 	Total Accuracy: 0.9200
# Trial 12
# 	Test RMSE: 0.0042
# 	Test Accuracy: 0.9450
# 	Total RMSE: 0.0052
# 	Total Accuracy: 0.9446
# Trial 13
# 	Test RMSE: 0.0101
# 	Test Accuracy: 0.9350
# 	Total RMSE: 0.0100
# 	Total Accuracy: 0.9407
# Trial 14
# 	Test RMSE: 0.0013
# 	Test Accuracy: 0.9113
# 	Total RMSE: 0.0023
# 	Total Accuracy: 0.9150
# Trial 15
# 	Test RMSE: 0.0116
# 	Test Accuracy: 0.9412
# 	Total RMSE: 0.0139
# 	Total Accuracy: 0.9414
# Trial 16
# 	Test RMSE: 0.0114
# 	Test Accuracy: 0.9506
# 	Total RMSE: 0.0113
# 	Total Accuracy: 0.9486
# Trial 17
# 	Test RMSE: 0.0036
# 	Test Accuracy: 0.9263
# 	Total RMSE: 0.0033
# 	Total Accuracy: 0.9296
# Trial 18
# 	Test RMSE: 0.0021
# 	Test Accuracy: 0.9375
# 	Total RMSE: 0.0031
# 	Total Accuracy: 0.9394
# Trial 19
# 	Test RMSE: 0.0069
# 	Test Accuracy: 0.9237
# 	Total RMSE: 0.0049
# 	Total Accuracy: 0.9352
# Trial 20
# 	Test RMSE: 0.0097
# 	Test Accuracy: 0.9312
# 	Total RMSE: 0.0121
# 	Total Accuracy: 0.9338
# Trial 21
# 	Test RMSE: 0.0167
# 	Test Accuracy: 0.9437
# 	Total RMSE: 0.0163
# 	Total Accuracy: 0.9441
# Trial 22
# 	Test RMSE: 0.0067
# 	Test Accuracy: 0.9456
# 	Total RMSE: 0.0053
# 	Total Accuracy: 0.9519
# Trial 23
# 	Test RMSE: 0.0221
# 	Test Accuracy: 0.9550
# 	Total RMSE: 0.0222
# 	Total Accuracy: 0.9484
# Trial 24
# 	Test RMSE: 0.0337
# 	Test Accuracy: 0.9150
# 	Total RMSE: 0.0321
# 	Total Accuracy: 0.9113
# Trial 25
# 	Test RMSE: 0.0134
# 	Test Accuracy: 0.9269
# 	Total RMSE: 0.0119
# 	Total Accuracy: 0.9271
# Trial 26
# 	Test RMSE: 0.0019
# 	Test Accuracy: 0.9375
# 	Total RMSE: 0.0047
# 	Total Accuracy: 0.9323
# Trial 27
# 	Test RMSE: 0.0274
# 	Test Accuracy: 0.9294
# 	Total RMSE: 0.0257
# 	Total Accuracy: 0.9297
# Trial 28
# 	Test RMSE: 0.0096
# 	Test Accuracy: 0.9306
# 	Total RMSE: 0.0078
# 	Total Accuracy: 0.9250
# Trial 29
# 	Test RMSE: 0.0046
# 	Test Accuracy: 0.9400
# 	Total RMSE: 0.0028
# 	Total Accuracy: 0.9403
#
# ####################
# 	Metrics for 30.0% missing
# 	Avg RMSE: 0.0127
# 	Avg Accuracy: 0.9388
# ####################
# Test for 40.0% missing data
# Trial 0
# 	Test RMSE: 0.0146
# 	Test Accuracy: 0.9287
# 	Total RMSE: 0.0103
# 	Total Accuracy: 0.9229
# Trial 1
# 	Test RMSE: 0.0132
# 	Test Accuracy: 0.9163
# 	Total RMSE: 0.0159
# 	Total Accuracy: 0.9174
# Trial 2
# 	Test RMSE: 0.0414
# 	Test Accuracy: 0.9019
# 	Total RMSE: 0.0382
# 	Total Accuracy: 0.9080
# Trial 3
# 	Test RMSE: 0.0072
# 	Test Accuracy: 0.9450
# 	Total RMSE: 0.0031
# 	Total Accuracy: 0.9363
# Trial 4
# 	Test RMSE: 0.0208
# 	Test Accuracy: 0.9269
# 	Total RMSE: 0.0198
# 	Total Accuracy: 0.9305
# Trial 5
# 	Test RMSE: 0.0104
# 	Test Accuracy: 0.9031
# 	Total RMSE: 0.0083
# 	Total Accuracy: 0.9101
# Trial 6
# 	Test RMSE: 0.0026
# 	Test Accuracy: 0.9094
# 	Total RMSE: 0.0024
# 	Total Accuracy: 0.9135
# Trial 7
# 	Test RMSE: 0.0066
# 	Test Accuracy: 0.9113
# 	Total RMSE: 0.0085
# 	Total Accuracy: 0.9087
# Trial 8
# 	Test RMSE: 0.0023
# 	Test Accuracy: 0.8906
# 	Total RMSE: 0.0044
# 	Total Accuracy: 0.8891
# Trial 9
# 	Test RMSE: 0.0200
# 	Test Accuracy: 0.8869
# 	Total RMSE: 0.0178
# 	Total Accuracy: 0.8820
# Trial 10
# 	Test RMSE: 0.0048
# 	Test Accuracy: 0.9075
# 	Total RMSE: 0.0052
# 	Total Accuracy: 0.9126
# Trial 11
# 	Test RMSE: 0.0093
# 	Test Accuracy: 0.9238
# 	Total RMSE: 0.0095
# 	Total Accuracy: 0.9187
# Trial 12
# 	Test RMSE: 0.0077
# 	Test Accuracy: 0.9331
# 	Total RMSE: 0.0077
# 	Total Accuracy: 0.9372
# Trial 13
# 	Test RMSE: 0.0090
# 	Test Accuracy: 0.9200
# 	Total RMSE: 0.0079
# 	Total Accuracy: 0.9234
# Trial 14
# 	Test RMSE: 0.0079
# 	Test Accuracy: 0.9419
# 	Total RMSE: 0.0080
# 	Total Accuracy: 0.9443
# Trial 15
# 	Test RMSE: 0.0148
# 	Test Accuracy: 0.9187
# 	Total RMSE: 0.0159
# 	Total Accuracy: 0.9226
# Trial 16
# 	Test RMSE: 0.0243
# 	Test Accuracy: 0.9200
# 	Total RMSE: 0.0212
# 	Total Accuracy: 0.9216
# Trial 17
# 	Test RMSE: 0.0258
# 	Test Accuracy: 0.9387
# 	Total RMSE: 0.0273
# 	Total Accuracy: 0.9359
# Trial 18
# 	Test RMSE: 0.0161
# 	Test Accuracy: 0.9269
# 	Total RMSE: 0.0164
# 	Total Accuracy: 0.9191
# Trial 19
# 	Test RMSE: 0.0577
# 	Test Accuracy: 0.8662
# 	Total RMSE: 0.0569
# 	Total Accuracy: 0.8575
# Trial 20
# 	Test RMSE: 0.0145
# 	Test Accuracy: 0.9313
# 	Total RMSE: 0.0105
# 	Total Accuracy: 0.9298
# Trial 21
# 	Test RMSE: 0.0135
# 	Test Accuracy: 0.9431
# 	Total RMSE: 0.0148
# 	Total Accuracy: 0.9332
# Trial 22
# 	Test RMSE: 0.0012
# 	Test Accuracy: 0.9294
# 	Total RMSE: 0.0033
# 	Total Accuracy: 0.9299
# Trial 23
# 	Test RMSE: 0.0010
# 	Test Accuracy: 0.9200
# 	Total RMSE: 0.0049
# 	Total Accuracy: 0.9211
# Trial 24
# 	Test RMSE: 0.0129
# 	Test Accuracy: 0.9000
# 	Total RMSE: 0.0116
# 	Total Accuracy: 0.9038
# Trial 25
# 	Test RMSE: 0.0119
# 	Test Accuracy: 0.9300
# 	Total RMSE: 0.0122
# 	Total Accuracy: 0.9314
# Trial 26
# 	Test RMSE: 0.0041
# 	Test Accuracy: 0.9275
# 	Total RMSE: 0.0054
# 	Total Accuracy: 0.9275
# Trial 27
# 	Test RMSE: 0.0120
# 	Test Accuracy: 0.8975
# 	Total RMSE: 0.0110
# 	Total Accuracy: 0.8999
# Trial 28
# 	Test RMSE: 0.0076
# 	Test Accuracy: 0.8794
# 	Total RMSE: 0.0098
# 	Total Accuracy: 0.8750
# Trial 29
# 	Test RMSE: 0.0280
# 	Test Accuracy: 0.9350
# 	Total RMSE: 0.0298
# 	Total Accuracy: 0.9366
#
# ####################
# 	Metrics for 40.0% missing
# 	Avg RMSE: 0.0139
# 	Avg Accuracy: 0.9167
# ####################

# %%
newresults = pd.DataFrame({
                        '1000KaggleRMSE': avg_rmses, 
                        '1000KaggleAcc': avg_accs, 
                        '1000KaggleSdRMSE': sd_rmses,
                        '1000KaggleSdAcc': sd_accs})
#results.to_csv("gain_results.csv")
#
newresults.head()
# Out:
#    1000KaggleRMSE  1000KaggleAcc  1000KaggleSdRMSE  1000KaggleSdAcc
# 0        0.004023       0.982487          0.002832         0.006039
# 1        0.006596       0.959388          0.004383         0.010633
# 2        0.012725       0.938762          0.010018         0.012309
# 3        0.013930       0.916654          0.011426         0.019586

# %%
results = pd.read_csv("gain_results.csv")

results = pd.concat([results, newresults], axis=1)

# %%
results.to_csv("gain_results.csv")

# %% [markdown]
# # 100 Samples Kaggle Data Experiment

# %%
# Encoding data and preparing for training
encoder = WOEncoder()
X_raw = encoder.fit_transform(subset_df)
X = X_raw.values

# select only 100 samples
sampler = np.random.permutation(X.shape[0])
X = X[sampler[:100], :]
dims = X.shape

test_df = pd.DataFrame(test_df.values[sampler[:100], :], columns=test_df.columns)

### Missing data introduction
p_miss = .2 # 20% missing data
p_miss_vec = p_miss * np.ones((dims[1], 1))
M = np.zeros(dims)

for i in range(dims[1]):
    A = np.random.uniform(0., 1., size=[dims[0], ])
    B = A > p_miss_vec[i]
    M[:, i] = 1.*B

# Train Test division
idx = np.random.permutation(dims[0])

Train_no = int(dims[0] * .8)
Test_no = dims[0] - Train_no

# Train / Test Features
trainX = X[idx[:Train_no], :]
testX = X[idx[Train_no:], :]

# Train / Test Features
trainM = M[idx[:Train_no], :]
testM = M[idx[Train_no:], :]

# %%
# Hyper params and network architectures
weights = [dims[1]*2, 64, 128, 64, dims[1]]

hyper_params = GAINHyper(batch_size=4, lr=0.001, 
                         alpha=10, epochs=30, p_hint=.9)

# Data Loaders for training
data_loader = DataLoader(torch.tensor(trainX, device=device).float(), 
                         batch_size=hyper_params.batch_size, 
                         shuffle=False)
mask_loader = DataLoader(torch.tensor(trainM, device=device).float(), 
                         batch_size=hyper_params.batch_size, 
                         shuffle=False)

# Generator and Discriminator
Generator = GAIN(weights=weights).to(device)
Discriminator = GAIN(weights=weights).to(device)

# Optimizers
optimizer_G = optim.Adam(Generator.parameters(), lr=hyper_params.lr)
optimizer_D = optim.Adam(Discriminator.parameters(), lr=hyper_params.lr)

# %%
train_GAIN(nets=(Generator, Discriminator), 
           optimizers=(optimizer_G, optimizer_D),
           dataloaders=(data_loader, mask_loader),
           batch_size=hyper_params.batch_size,
           alpha=hyper_params.alpha,
           p_hint=hyper_params.p_hint,
           epochs=hyper_params.epochs, verbose=False)

# %% [markdown]
# ## Testing and Metrics for single experiment

# %%
# Test set
imputed_data, rmse = imputator(Generator, testX, testM, encoder, cuda=True)
testDecoded = encoder.smart_decode(testX)
means = []
for col in imputed_data.columns:
    mean = np.mean(np.where(imputed_data[col].values == testDecoded[col].values, 1, 0))
    means.append(mean)

accuracy = np.mean(np.array(means))
print("RMSE: {}\nAccuracy: {}".format(rmse, accuracy))
# Out:
# RMSE: 0.01770074737839651
# Accuracy: 0.9625

# %%
# Entire set
imputed_data, rmse = imputator(Generator, X, M, encoder, cuda=True)

means = []
for col in imputed_data.columns:
    mean = np.mean(np.where(imputed_data[col].values == test_df[col].values, 1, 0))
    means.append(mean)

accuracy = np.mean(np.array(means))
print("RMSE: {}\nAccuracy: {}".format(rmse, accuracy))
# Out:
# RMSE: 0.0192599753542593
# Accuracy: 0.95

# %% [markdown]
# ## Multiple Trial Training and Testing

# %%
# Encoding data and preparing for training
encoder = WOEncoder()
X_raw = encoder.fit_transform(subset_df)
X = X_raw.values

# select only 100 samples
sampler = np.random.permutation(X.shape[0])
X = X[sampler[:100], :]
dims = X.shape

test_df = pd.DataFrame(test_df.values[sampler[:100], :], columns=test_df.columns)

# %%
trials = 30
pmissing = [.1, .2, .3, .4]
avg_rmses = []
sd_rmses = []
avg_accs = []
sd_accs = []

print("SurvGAIN test on Kaggle {} samples".format(dims[0]))

for p in pmissing:
    print("Test for {}% missing data".format(100*p))
    rmses = []
    accs = []
    for t in range(trials):
        print("Trial {}".format(t))
        #############
        # Preparing #
        #############

        Xt, mt, M = generate_trial_data(X, p_miss=p)
        trainX, testX = Xt
        trainM, testM = mt

        # Hyper params and network architectures
        weights = [dims[1]*2, 64, 128, 64, dims[1]]

        hyper_params = GAINHyper(batch_size=32, lr=0.001, 
                                alpha=100, epochs=30, p_hint=.9)

        # Data Loaders for training
        data_loader = DataLoader(torch.tensor(trainX, device=device).float(), 
                                batch_size=hyper_params.batch_size, 
                                shuffle=False)
        mask_loader = DataLoader(torch.tensor(trainM, device=device).float(), 
                                batch_size=hyper_params.batch_size, 
                                shuffle=False)

        # Generator and Discriminator
        Generator = GAIN(weights=weights).to(device)
        Discriminator = GAIN(weights=weights).to(device)

        # Optimizers
        optimizer_G = optim.Adam(Generator.parameters(), lr=hyper_params.lr)
        optimizer_D = optim.Adam(Discriminator.parameters(), lr=hyper_params.lr)

        ############
        # Training #
        ############
        train_GAIN(nets=(Generator, Discriminator), 
            optimizers=(optimizer_G, optimizer_D),
            dataloaders=(data_loader, mask_loader),
            batch_size=hyper_params.batch_size,
            alpha=hyper_params.alpha,
            p_hint=hyper_params.p_hint,
            epochs=hyper_params.epochs, verbose=False)
        

        ###########
        # Testing #
        ###########
        # Test set
        imputed_data, rmse = imputator(Generator, testX, testM, encoder, cuda=True)
        testDecoded = encoder.smart_decode(testX)
        means = []
        for col in imputed_data.columns:
            mean = np.mean(np.where(imputed_data[col].values == testDecoded[col].values, 1, 0))
            means.append(mean)

        accuracy = np.mean(np.array(means))
        print("\tTest RMSE: {0:.4f}".format(rmse))
        print("\tTest Accuracy: {0:.4f}".format(accuracy))


        # Entire set
        imputed_data, rmse = imputator(Generator, X, M, encoder, cuda=True)
        testDecoded = encoder.smart_decode(testX)
        means = []
        for col in imputed_data.columns:
            mean = np.mean(np.where(imputed_data[col].values == test_df[col].values, 1, 0))
            means.append(mean)

        accuracy = np.mean(np.array(means))
        print("\tTotal RMSE: {0:.4f}".format(rmse))
        print("\tTotal Accuracy: {0:.4f}".format(accuracy))
        rmses.append(rmse)
        accs.append(accuracy)


    ### Average metrics for experiment

    # RMSE
    mean_rmse = np.mean(np.array(rmses))
    avg_rmses.append(mean_rmse)
    sd_rmses.append(np.std(np.array(rmses)))
    # Accuracy
    mean_acc = np.mean(np.array(accs))
    avg_accs.append(mean_acc)
    sd_accs.append(np.std(np.array(accs)))
    print()
    print('#'*20)
    print("\tMetrics for {}% missing".format(100*p))
    print("\tAvg RMSE: {0:.4f}".format(mean_rmse))
    print("\tAvg Accuracy: {0:.4f}".format(mean_acc))
    print('#'*20)
# Out:
# SurvGAIN test on Kaggle 100 samples
# Test for 10.0% missing data
# Trial 0
# 	Test RMSE: 0.0090
# 	Test Accuracy: 0.9500
# 	Total RMSE: 0.0060
# 	Total Accuracy: 0.9550
# Trial 1
# 	Test RMSE: 0.0042
# 	Test Accuracy: 0.9812
# 	Total RMSE: 0.0194
# 	Total Accuracy: 0.9675
# Trial 2
# 	Test RMSE: 0.0127
# 	Test Accuracy: 0.9313
# 	Total RMSE: 0.0098
# 	Total Accuracy: 0.9575
# Trial 3
# 	Test RMSE: 0.0033
# 	Test Accuracy: 0.9688
# 	Total RMSE: 0.0017
# 	Total Accuracy: 0.9525
# Trial 4
# 	Test RMSE: 0.0003
# 	Test Accuracy: 0.9313
# 	Total RMSE: 0.0054
# 	Total Accuracy: 0.9325
# Trial 5
# 	Test RMSE: 0.0097
# 	Test Accuracy: 0.9500
# 	Total RMSE: 0.0043
# 	Total Accuracy: 0.9587
# Trial 6
# 	Test RMSE: 0.0199
# 	Test Accuracy: 0.9375
# 	Total RMSE: 0.0017
# 	Total Accuracy: 0.9438
# Trial 7
# 	Test RMSE: 0.0216
# 	Test Accuracy: 0.9500
# 	Total RMSE: 0.0060
# 	Total Accuracy: 0.9563
# Trial 8
# 	Test RMSE: 0.0211
# 	Test Accuracy: 0.9688
# 	Total RMSE: 0.0042
# 	Total Accuracy: 0.9587
# Trial 9
# 	Test RMSE: 0.0186
# 	Test Accuracy: 0.9625
# 	Total RMSE: 0.0022
# 	Total Accuracy: 0.9525
# Trial 10
# 	Test RMSE: 0.0163
# 	Test Accuracy: 0.9500
# 	Total RMSE: 0.0059
# 	Total Accuracy: 0.9512
# Trial 11
# 	Test RMSE: 0.0080
# 	Test Accuracy: 0.9375
# 	Total RMSE: 0.0074
# 	Total Accuracy: 0.9300
# Trial 12
# 	Test RMSE: 0.0337
# 	Test Accuracy: 0.9375
# 	Total RMSE: 0.0070
# 	Total Accuracy: 0.9525
# Trial 13
# 	Test RMSE: 0.0008
# 	Test Accuracy: 0.9625
# 	Total RMSE: 0.0052
# 	Total Accuracy: 0.9537
# Trial 14
# 	Test RMSE: 0.0076
# 	Test Accuracy: 0.9375
# 	Total RMSE: 0.0055
# 	Total Accuracy: 0.9363
# Trial 15
# 	Test RMSE: 0.0207
# 	Test Accuracy: 0.9500
# 	Total RMSE: 0.0085
# 	Total Accuracy: 0.9575
# Trial 16
# 	Test RMSE: 0.0094
# 	Test Accuracy: 0.9563
# 	Total RMSE: 0.0004
# 	Total Accuracy: 0.9487
# Trial 17
# 	Test RMSE: 0.0063
# 	Test Accuracy: 0.9563
# 	Total RMSE: 0.0039
# 	Total Accuracy: 0.9500
# Trial 18
# 	Test RMSE: 0.0168
# 	Test Accuracy: 0.9812
# 	Total RMSE: 0.0043
# 	Total Accuracy: 0.9688
# Trial 19
# 	Test RMSE: 0.0190
# 	Test Accuracy: 0.9625
# 	Total RMSE: 0.0015
# 	Total Accuracy: 0.9550
# Trial 20
# 	Test RMSE: 0.0140
# 	Test Accuracy: 0.9438
# 	Total RMSE: 0.0047
# 	Total Accuracy: 0.9563
# Trial 21
# 	Test RMSE: 0.0200
# 	Test Accuracy: 0.9688
# 	Total RMSE: 0.0128
# 	Total Accuracy: 0.9575
# Trial 22
# 	Test RMSE: 0.0102
# 	Test Accuracy: 0.9625
# 	Total RMSE: 0.0031
# 	Total Accuracy: 0.9663
# Trial 23
# 	Test RMSE: 0.0268
# 	Test Accuracy: 0.9438
# 	Total RMSE: 0.0119
# 	Total Accuracy: 0.9650
# Trial 24
# 	Test RMSE: 0.0079
# 	Test Accuracy: 0.9562
# 	Total RMSE: 0.0001
# 	Total Accuracy: 0.9475
# Trial 25
# 	Test RMSE: 0.0138
# 	Test Accuracy: 0.9500
# 	Total RMSE: 0.0067
# 	Total Accuracy: 0.9487
# Trial 26
# 	Test RMSE: 0.0048
# 	Test Accuracy: 0.9312
# 	Total RMSE: 0.0048
# 	Total Accuracy: 0.9563
# Trial 27
# 	Test RMSE: 0.0060
# 	Test Accuracy: 0.9688
# 	Total RMSE: 0.0054
# 	Total Accuracy: 0.9525
# Trial 28
# 	Test RMSE: 0.0237
# 	Test Accuracy: 0.9500
# 	Total RMSE: 0.0079
# 	Total Accuracy: 0.9500
# Trial 29
# 	Test RMSE: 0.0086
# 	Test Accuracy: 0.9688
# 	Total RMSE: 0.0119
# 	Total Accuracy: 0.9637
#
# ####################
# 	Metrics for 10.0% missing
# 	Avg RMSE: 0.0060
# 	Avg Accuracy: 0.9534
# ####################
# Test for 20.0% missing data
# Trial 0
# 	Test RMSE: 0.0055
# 	Test Accuracy: 0.9125
# 	Total RMSE: 0.0018
# 	Total Accuracy: 0.9175
# Trial 1
# 	Test RMSE: 0.0362
# 	Test Accuracy: 0.9187
# 	Total RMSE: 0.0205
# 	Total Accuracy: 0.9000
# Trial 2
# 	Test RMSE: 0.0070
# 	Test Accuracy: 0.9125
# 	Total RMSE: 0.0129
# 	Total Accuracy: 0.9000
# Trial 3
# 	Test RMSE: 0.0041
# 	Test Accuracy: 0.9437
# 	Total RMSE: 0.0083
# 	Total Accuracy: 0.9187
# Trial 4
# 	Test RMSE: 0.0067
# 	Test Accuracy: 0.9187
# 	Total RMSE: 0.0164
# 	Total Accuracy: 0.9062
# Trial 5
# 	Test RMSE: 0.0134
# 	Test Accuracy: 0.9187
# 	Total RMSE: 0.0033
# 	Total Accuracy: 0.9187
# Trial 6
# 	Test RMSE: 0.0422
# 	Test Accuracy: 0.8875
# 	Total RMSE: 0.0370
# 	Total Accuracy: 0.9050
# Trial 7
# 	Test RMSE: 0.0195
# 	Test Accuracy: 0.9375
# 	Total RMSE: 0.0118
# 	Total Accuracy: 0.9250
# Trial 8
# 	Test RMSE: 0.0135
# 	Test Accuracy: 0.9062
# 	Total RMSE: 0.0014
# 	Total Accuracy: 0.8912
# Trial 9
# 	Test RMSE: 0.0020
# 	Test Accuracy: 0.8750
# 	Total RMSE: 0.0012
# 	Total Accuracy: 0.9025
# Trial 10
# 	Test RMSE: 0.0325
# 	Test Accuracy: 0.9312
# 	Total RMSE: 0.0161
# 	Total Accuracy: 0.9038
# Trial 11
# 	Test RMSE: 0.0417
# 	Test Accuracy: 0.9000
# 	Total RMSE: 0.0226
# 	Total Accuracy: 0.9175
# Trial 12
# 	Test RMSE: 0.0149
# 	Test Accuracy: 0.9062
# 	Total RMSE: 0.0028
# 	Total Accuracy: 0.9312
# Trial 13
# 	Test RMSE: 0.0124
# 	Test Accuracy: 0.9250
# 	Total RMSE: 0.0073
# 	Total Accuracy: 0.8862
# Trial 14
# 	Test RMSE: 0.0054
# 	Test Accuracy: 0.8875
# 	Total RMSE: 0.0012
# 	Total Accuracy: 0.9012
# Trial 15
# 	Test RMSE: 0.0173
# 	Test Accuracy: 0.9375
# 	Total RMSE: 0.0056
# 	Total Accuracy: 0.9012
# Trial 16
# 	Test RMSE: 0.0056
# 	Test Accuracy: 0.8938
# 	Total RMSE: 0.0043
# 	Total Accuracy: 0.8912
# Trial 17
# 	Test RMSE: 0.0007
# 	Test Accuracy: 0.9125
# 	Total RMSE: 0.0110
# 	Total Accuracy: 0.9037
# Trial 18
# 	Test RMSE: 0.0118
# 	Test Accuracy: 0.8875
# 	Total RMSE: 0.0175
# 	Total Accuracy: 0.8988
# Trial 19
# 	Test RMSE: 0.0051
# 	Test Accuracy: 0.8500
# 	Total RMSE: 0.0004
# 	Total Accuracy: 0.9200
# Trial 20
# 	Test RMSE: 0.0076
# 	Test Accuracy: 0.9313
# 	Total RMSE: 0.0086
# 	Total Accuracy: 0.9050
# Trial 21
# 	Test RMSE: 0.0172
# 	Test Accuracy: 0.9187
# 	Total RMSE: 0.0138
# 	Total Accuracy: 0.9062
# Trial 22
# 	Test RMSE: 0.0165
# 	Test Accuracy: 0.9125
# 	Total RMSE: 0.0019
# 	Total Accuracy: 0.9250
# Trial 23
# 	Test RMSE: 0.0075
# 	Test Accuracy: 0.9125
# 	Total RMSE: 0.0076
# 	Total Accuracy: 0.9075
# Trial 24
# 	Test RMSE: 0.0231
# 	Test Accuracy: 0.8625
# 	Total RMSE: 0.0100
# 	Total Accuracy: 0.8862
# Trial 25
# 	Test RMSE: 0.0105
# 	Test Accuracy: 0.9250
# 	Total RMSE: 0.0083
# 	Total Accuracy: 0.9000
# Trial 26
# 	Test RMSE: 0.0250
# 	Test Accuracy: 0.9062
# 	Total RMSE: 0.0061
# 	Total Accuracy: 0.9100
# Trial 27
# 	Test RMSE: 0.0235
# 	Test Accuracy: 0.8875
# 	Total RMSE: 0.0151
# 	Total Accuracy: 0.9138
# Trial 28
# 	Test RMSE: 0.0172
# 	Test Accuracy: 0.8562
# 	Total RMSE: 0.0111
# 	Total Accuracy: 0.8950
# Trial 29
# 	Test RMSE: 0.0252
# 	Test Accuracy: 0.9438
# 	Total RMSE: 0.0078
# 	Total Accuracy: 0.9263
#
# ####################
# 	Metrics for 20.0% missing
# 	Avg RMSE: 0.0098
# 	Avg Accuracy: 0.9072
# ####################
# Test for 30.0% missing data
# Trial 0
# 	Test RMSE: 0.0965
# 	Test Accuracy: 0.8313
# 	Total RMSE: 0.0260
# 	Total Accuracy: 0.8413
# Trial 1
# 	Test RMSE: 0.0025
# 	Test Accuracy: 0.8625
# 	Total RMSE: 0.0123
# 	Total Accuracy: 0.8588
# Trial 2
# 	Test RMSE: 0.0146
# 	Test Accuracy: 0.8688
# 	Total RMSE: 0.0020
# 	Total Accuracy: 0.8588
# Trial 3
# 	Test RMSE: 0.0173
# 	Test Accuracy: 0.8750
# 	Total RMSE: 0.0035
# 	Total Accuracy: 0.8550
# Trial 4
# 	Test RMSE: 0.0368
# 	Test Accuracy: 0.8500
# 	Total RMSE: 0.0198
# 	Total Accuracy: 0.8488
# Trial 5
# 	Test RMSE: 0.0355
# 	Test Accuracy: 0.8750
# 	Total RMSE: 0.0062
# 	Total Accuracy: 0.8450
# Trial 6
# 	Test RMSE: 0.0205
# 	Test Accuracy: 0.8125
# 	Total RMSE: 0.0106
# 	Total Accuracy: 0.8675
# Trial 7
# 	Test RMSE: 0.0122
# 	Test Accuracy: 0.8625
# 	Total RMSE: 0.0032
# 	Total Accuracy: 0.8612
# Trial 8
# 	Test RMSE: 0.0298
# 	Test Accuracy: 0.8438
# 	Total RMSE: 0.0209
# 	Total Accuracy: 0.8675
# Trial 9
# 	Test RMSE: 0.0163
# 	Test Accuracy: 0.8313
# 	Total RMSE: 0.0084
# 	Total Accuracy: 0.8413
# Trial 10
# 	Test RMSE: 0.0335
# 	Test Accuracy: 0.8625
# 	Total RMSE: 0.0092
# 	Total Accuracy: 0.8525
# Trial 11
# 	Test RMSE: 0.0427
# 	Test Accuracy: 0.7937
# 	Total RMSE: 0.0192
# 	Total Accuracy: 0.8638
# Trial 12
# 	Test RMSE: 0.0617
# 	Test Accuracy: 0.8250
# 	Total RMSE: 0.0097
# 	Total Accuracy: 0.8525
# Trial 13
# 	Test RMSE: 0.0095
# 	Test Accuracy: 0.8250
# 	Total RMSE: 0.0164
# 	Total Accuracy: 0.8300
# Trial 14
# 	Test RMSE: 0.0165
# 	Test Accuracy: 0.8687
# 	Total RMSE: 0.0060
# 	Total Accuracy: 0.8700
# Trial 15
# 	Test RMSE: 0.0058
# 	Test Accuracy: 0.9000
# 	Total RMSE: 0.0116
# 	Total Accuracy: 0.8875
# Trial 16
# 	Test RMSE: 0.0032
# 	Test Accuracy: 0.8812
# 	Total RMSE: 0.0394
# 	Total Accuracy: 0.8662
# Trial 17
# 	Test RMSE: 0.0120
# 	Test Accuracy: 0.8687
# 	Total RMSE: 0.0050
# 	Total Accuracy: 0.8750
# Trial 18
# 	Test RMSE: 0.0154
# 	Test Accuracy: 0.8875
# 	Total RMSE: 0.0028
# 	Total Accuracy: 0.8850
# Trial 19
# 	Test RMSE: 0.0269
# 	Test Accuracy: 0.8875
# 	Total RMSE: 0.0191
# 	Total Accuracy: 0.8700
# Trial 20
# 	Test RMSE: 0.0008
# 	Test Accuracy: 0.8500
# 	Total RMSE: 0.0081
# 	Total Accuracy: 0.8612
# Trial 21
# 	Test RMSE: 0.0641
# 	Test Accuracy: 0.8375
# 	Total RMSE: 0.0134
# 	Total Accuracy: 0.8650
# Trial 22
# 	Test RMSE: 0.0664
# 	Test Accuracy: 0.8688
# 	Total RMSE: 0.0336
# 	Total Accuracy: 0.8662
# Trial 23
# 	Test RMSE: 0.0328
# 	Test Accuracy: 0.8813
# 	Total RMSE: 0.0281
# 	Total Accuracy: 0.8438
# Trial 24
# 	Test RMSE: 0.0082
# 	Test Accuracy: 0.8687
# 	Total RMSE: 0.0050
# 	Total Accuracy: 0.8512
# Trial 25
# 	Test RMSE: 0.0252
# 	Test Accuracy: 0.8125
# 	Total RMSE: 0.0061
# 	Total Accuracy: 0.8550
# Trial 26
# 	Test RMSE: 0.0103
# 	Test Accuracy: 0.8813
# 	Total RMSE: 0.0033
# 	Total Accuracy: 0.8688
# Trial 27
# 	Test RMSE: 0.0264
# 	Test Accuracy: 0.8750
# 	Total RMSE: 0.0123
# 	Total Accuracy: 0.8638
# Trial 28
# 	Test RMSE: 0.0267
# 	Test Accuracy: 0.8375
# 	Total RMSE: 0.0316
# 	Total Accuracy: 0.8550
# Trial 29
# 	Test RMSE: 0.0196
# 	Test Accuracy: 0.8875
# 	Total RMSE: 0.0220
# 	Total Accuracy: 0.8900
#
# ####################
# 	Metrics for 30.0% missing
# 	Avg RMSE: 0.0138
# 	Avg Accuracy: 0.8606
# ####################
# Test for 40.0% missing data
# Trial 0
# 	Test RMSE: 0.0024
# 	Test Accuracy: 0.7875
# 	Total RMSE: 0.0045
# 	Total Accuracy: 0.7950
# Trial 1
# 	Test RMSE: 0.0551
# 	Test Accuracy: 0.8000
# 	Total RMSE: 0.0741
# 	Total Accuracy: 0.8025
# Trial 2
# 	Test RMSE: 0.0055
# 	Test Accuracy: 0.8313
# 	Total RMSE: 0.0191
# 	Total Accuracy: 0.8137
# Trial 3
# 	Test RMSE: 0.0425
# 	Test Accuracy: 0.7625
# 	Total RMSE: 0.0541
# 	Total Accuracy: 0.7788
# Trial 4
# 	Test RMSE: 0.0229
# 	Test Accuracy: 0.8187
# 	Total RMSE: 0.0053
# 	Total Accuracy: 0.8225
# Trial 5
# 	Test RMSE: 0.0686
# 	Test Accuracy: 0.7375
# 	Total RMSE: 0.0688
# 	Total Accuracy: 0.7913
# Trial 6
# 	Test RMSE: 0.0850
# 	Test Accuracy: 0.8125
# 	Total RMSE: 0.0651
# 	Total Accuracy: 0.7925
# Trial 7
# 	Test RMSE: 0.0319
# 	Test Accuracy: 0.8000
# 	Total RMSE: 0.0171
# 	Total Accuracy: 0.8462
# Trial 8
# 	Test RMSE: 0.0387
# 	Test Accuracy: 0.7688
# 	Total RMSE: 0.0042
# 	Total Accuracy: 0.8113
# Trial 9
# 	Test RMSE: 0.0205
# 	Test Accuracy: 0.8063
# 	Total RMSE: 0.0021
# 	Total Accuracy: 0.8313
# Trial 10
# 	Test RMSE: 0.0701
# 	Test Accuracy: 0.7937
# 	Total RMSE: 0.0347
# 	Total Accuracy: 0.7800
# Trial 11
# 	Test RMSE: 0.0107
# 	Test Accuracy: 0.7688
# 	Total RMSE: 0.0281
# 	Total Accuracy: 0.8175
# Trial 12
# 	Test RMSE: 0.0462
# 	Test Accuracy: 0.8500
# 	Total RMSE: 0.0470
# 	Total Accuracy: 0.8137
# Trial 13
# 	Test RMSE: 0.0155
# 	Test Accuracy: 0.7375
# 	Total RMSE: 0.0033
# 	Total Accuracy: 0.7837
# Trial 14
# 	Test RMSE: 0.0266
# 	Test Accuracy: 0.8875
# 	Total RMSE: 0.0135
# 	Total Accuracy: 0.8462
# Trial 15
# 	Test RMSE: 0.0380
# 	Test Accuracy: 0.8125
# 	Total RMSE: 0.0243
# 	Total Accuracy: 0.7937
# Trial 16
# 	Test RMSE: 0.0628
# 	Test Accuracy: 0.8250
# 	Total RMSE: 0.0559
# 	Total Accuracy: 0.7775
# Trial 17
# 	Test RMSE: 0.0319
# 	Test Accuracy: 0.7875
# 	Total RMSE: 0.0288
# 	Total Accuracy: 0.7975
# Trial 18
# 	Test RMSE: 0.0033
# 	Test Accuracy: 0.8500
# 	Total RMSE: 0.0213
# 	Total Accuracy: 0.8087
# Trial 19
# 	Test RMSE: 0.0293
# 	Test Accuracy: 0.8188
# 	Total RMSE: 0.0235
# 	Total Accuracy: 0.8237
# Trial 20
# 	Test RMSE: 0.0106
# 	Test Accuracy: 0.8063
# 	Total RMSE: 0.0199
# 	Total Accuracy: 0.8137
# Trial 21
# 	Test RMSE: 0.0070
# 	Test Accuracy: 0.7375
# 	Total RMSE: 0.0025
# 	Total Accuracy: 0.8000
# Trial 22
# 	Test RMSE: 0.0628
# 	Test Accuracy: 0.8125
# 	Total RMSE: 0.0706
# 	Total Accuracy: 0.8025
# Trial 23
# 	Test RMSE: 0.0039
# 	Test Accuracy: 0.8750
# 	Total RMSE: 0.0253
# 	Total Accuracy: 0.8337
# Trial 24
# 	Test RMSE: 0.0033
# 	Test Accuracy: 0.8313
# 	Total RMSE: 0.0000
# 	Total Accuracy: 0.8187
# Trial 25
# 	Test RMSE: 0.0295
# 	Test Accuracy: 0.7688
# 	Total RMSE: 0.0068
# 	Total Accuracy: 0.8175
# Trial 26
# 	Test RMSE: 0.0005
# 	Test Accuracy: 0.8125
# 	Total RMSE: 0.0292
# 	Total Accuracy: 0.8013
# Trial 27
# 	Test RMSE: 0.0578
# 	Test Accuracy: 0.8438
# 	Total RMSE: 0.0193
# 	Total Accuracy: 0.8300
# Trial 28
# 	Test RMSE: 0.0255
# 	Test Accuracy: 0.8188
# 	Total RMSE: 0.0527
# 	Total Accuracy: 0.8037
# Trial 29
# 	Test RMSE: 0.0785
# 	Test Accuracy: 0.8250
# 	Total RMSE: 0.0404
# 	Total Accuracy: 0.7850
#
# ####################
# 	Metrics for 40.0% missing
# 	Avg RMSE: 0.0287
# 	Avg Accuracy: 0.8078
# ####################

# %%
newresults = pd.DataFrame({
                        '100KaggleRMSE': avg_rmses, 
                        '100KaggleAcc': avg_accs, 
                        '100KaggleSdRMSE': sd_rmses,
                        '100KaggleSdAcc': sd_accs})
#results.to_csv("gain_results.csv")
#
newresults.head()
# Out:
#    100KaggleRMSE  100KaggleAcc  100KaggleSdRMSE  100KaggleSdAcc
# 0       0.005987      0.953417         0.004021        0.009054
# 1       0.009790      0.907167         0.007816        0.011775
# 2       0.013827      0.860583         0.009955        0.013547
# 3       0.028705      0.807792         0.022383        0.018579

# %%
results = pd.read_csv("gain_results.csv")

results = pd.concat([results, newresults], axis=1)
results.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ...  100KaggleSdRMSE  100KaggleSdAcc
# 0           0             0  ...         0.004021        0.009054
# 1           1             1  ...         0.007816        0.011775
# 2           2             2  ...         0.009955        0.013547
# 3           3             3  ...         0.022383        0.018579
#
# [4 rows x 15 columns]

# %%
results.to_csv("gain_results.csv")
